# %% [markdown]
# # Data Scrapping notebook for devsearch engine
#
# This notebook is used to scrape and explore data to form the dataset for the devsearch engine. It includes functions to scrape data from various sources, clean it, and prepare it for analysis.

# %%
import polars as pl
from trafilatura.spider import focused_crawler
from trafilatura.sitemaps import sitemap_search
from trafilatura import bare_extraction

# %%
to_visit, known_links = focused_crawler("https://docs.python.org/3.10/", max_seen_urls = 1, max_known_urls=15)
to_visit
# Out:
# ['https://docs.python.org/search.html',
#  'https://docs.python.org/3.4/',
#  'https://docs.python.org/contents.html',
#  'https://docs.python.org/3.11/',
#  'https://docs.python.org/about.html',
#  'https://docs.python.org/3.2/',
#  'https://docs.python.org/download.html',
#  'https://docs.python.org/extending/index.html',
#  'https://docs.python.org/3.6/',
#  'https://docs.python.org/3.9/',
#  'https://docs.python.org/3.7/',
#  'https://docs.python.org/bugs.html',
#  'https://docs.python.org/2.6/',
#  'https://docs.python.org/glossary.html',
#  'https://docs.python.org/genindex.html',
#  'https://docs.python.org/distributing/index.html',
#  'https://docs.python.org/3.5/',
#  'https://docs.python.org/copyright.html',
#  'https://docs.python.org/faq/index.html',
#  'https://docs.python.org/reference/index.html',
#  'https://docs.python.org/whatsnew/3.13.html',
#  'https://docs.python.org/license.html',
#  'https://docs.python.org/whatsnew/index.html',
#  'https://docs.python.org/c-api/index.html',
#  'https://docs.python.org/3.14/',
#  'https://docs.python.org/tutorial/index.html',
#  'https://docs.python.org/using/index.html',
#  'https://docs.python.org/py-modindex.html',
#  'https://docs.python.org/distutils/index.html',
#  'https://docs.python.org/whatsnew/3.3.html',
#  'https://docs.python.org/install/index.html',
#  'https://docs.python.org/whatsnew/3.1.html',
#  'https://docs.python.org/modindex.html',
#  'https://docs.python.org/documenting/index.html',
#  'https://docs.python.org/whatsnew/3.10.html',
#  'https://docs.python.org/c-api/object.html#c.PyObject_Hash',
#  'https://docs.python.org/c-api/module.html#c.PyModule_GetFilenameObject',
#  'https://docs.python.org/library/pathlib.html#module-pathlib',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.isolated',
#  'https://docs.python.org/c-api/slice.html#c.PySlice_Unpack',
#  'https://docs.python.org/library/platform.html#module-platform',
#  'https://docs.python.org#c-api-deprecations',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.hash_seed',
#  'https://docs.python.org/library/inspect.html#inspect.iscoroutinefunction',
#  'https://docs.python.org/library/ast.html#module-ast',
#  'https://docs.python.org/library/ssl.html#ssl.SSLContext.set_npn_protocols',
#  'https://docs.python.org/c-api/typeobj.html#c.Py_TPFLAGS_IMMUTABLETYPE',
#  'https://docs.python.org/c-api/init.html#c.Py_HashRandomizationFlag',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.pathconfig_warnings',
#  'https://docs.python.org/c-api/init.html#c.Py_DontWriteBytecodeFlag',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.site_import',
#  'https://docs.python.org/library/locale.html#locale.getlocale',
#  'https://docs.python.org/library/importlib.html#importlib.util.cache_from_source',
#  'https://docs.python.org/library/asyncio-policy.html#asyncio.MultiLoopChildWatcher',
#  'https://docs.python.org/library/locale.html#locale.getdefaultlocale',
#  'https://docs.python.org/library/multiprocessing.html#module-multiprocessing',
#  'https://docs.python.org/library/asyncio-policy.html#asyncio.SafeChildWatcher',
#  'https://docs.python.org#id3',
#  'https://docs.python.org/library/sys.html#sys.prefix',
#  'https://docs.python.org/library/pkgutil.html#pkgutil.get_loader',
#  'https://docs.python.org/library/importlib.html#importlib.machinery.ModuleSpec.loader',
#  'https://docs.python.org/library/platform.html#platform.java_ver',
#  'https://docs.python.org/c-api/init.html#c.Py_GetPath',
#  'https://docs.python.org/library/typing.html#typing.ByteString',
#  'https://docs.python.org/library/threading.html#threading.RLock',
#  'https://docs.python.org/library/wsgiref.html#module-wsgiref',
#  'https://docs.python.org/library/asyncio.html#module-asyncio',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.use_environment',
#  'https://docs.python.org/using/cmdline.html#envvar-PYTHONLEGACYWINDOWSFSENCODING',
#  'https://docs.python.org/c-api/init.html#c.Py_IgnoreEnvironmentFlag',
#  'https://docs.python.org/library/types.html#module-types',
#  'https://docs.python.org/library/asyncio-policy.html#asyncio.get_child_watcher',
#  'https://docs.python.org/library/importlib.html#module-importlib',
#  'https://docs.python.org/reference/datamodel.html#codeobject.co_lnotab',
#  'https://docs.python.org/library/locale.html#locale.getencoding',
#  'https://docs.python.org/library/http.server.html#http.server.CGIHTTPRequestHandler',
#  'https://docs.python.org/c-api/import.html#c.PyImport_ImportModule',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.verbose',
#  'https://docs.python.org/library/types.html#types.CodeType',
#  'https://docs.python.org#pending-removal-in-python-3-15',
#  'https://docs.python.org/library/sqlite3.html#module-sqlite3',
#  'https://docs.python.org/library/sys.html#sys.warnoptions',
#  'https://docs.python.org/c-api/init.html#c.PyThread_set_key_value',
#  'https://docs.python.org/reference/compound_stmts.html#if',
#  'https://docs.python.org/library/functions.html#int',
#  'https://docs.python.org/library/importlib.html#importlib.machinery.ModuleSpec.cached',
#  'https://docs.python.org/library/wave.html#wave.Wave_read.getmark',
#  'https://docs.python.org/library/multiprocessing.html#multiprocessing.get_context',
#  'https://docs.python.org/c-api/typeobj.html#c.Py_TPFLAGS_HAVE_FINALIZE',
#  'https://docs.python.org/c-api/init.html#c.Py_IsolatedFlag',
#  'https://docs.python.org/library/importlib.html#importlib.machinery.ModuleSpec.parent',
#  'https://docs.python.org/c-api/init.html#c.PyThread_tss_set',
#  'https://docs.python.org/c-api/init_config.html#c.PyPreConfig.legacy_windows_fs_encoding',
#  'https://docs.python.org/library/threading.html#threading.current_thread',
#  'https://docs.python.org/c-api/codec.html#c.PyCodec_Encode',
#  'https://docs.python.org/c-api/init.html#c.PyThread_tss_get',
#  'https://docs.python.org/library/pathlib.html#pathlib.PurePath.is_relative_to',
#  'https://docs.python.org/library/sqlite3.html#sqlite3.Cursor.execute',
#  'https://docs.python.org/library/threading.html#threading.Thread.setDaemon',
#  'https://docs.python.org/library/importlib.html#importlib.util.find_spec',
#  'https://docs.python.org/library/typing.html#typing.no_type_check_decorator',
#  'https://docs.python.org/c-api/init.html#c.PyThread_get_key_value',
#  'https://docs.python.org#pending-removal-in-future-versions',
#  'https://docs.python.org/library/sys.html#sys.base_exec_prefix',
#  'https://docs.python.org/c-api/init.html#c.Py_InitializeFromConfig',
#  'https://docs.python.org/library/ssl.html#ssl.SSLContext',
#  'https://docs.python.org/library/stdtypes.html#dict',
#  'https://docs.python.org/library/threading.html#threading.Condition.notify_all',
#  'https://docs.python.org/c-api/module.html#c.PyModule_GetFilename',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.buffered_stdio',
#  'https://docs.python.org/library/urllib.request.html#urllib.request.URLopener',
#  'https://docs.python.org#pending-removal-in-python-3-16',
#  'https://docs.python.org/c-api/init.html#c.PyThread_create_key',
#  'https://docs.python.org/library/asyncio-policy.html#asyncio.FastChildWatcher',
#  'https://docs.python.org/reference/datamodel.html#module.__cached__',
#  'https://docs.python.org/library/urllib.request.html#urllib.request.FancyURLopener',
#  'https://docs.python.org/library/collections.abc.html#module-collections.abc',
#  'https://docs.python.org/c-api/init.html#c.Py_LegacyWindowsFSEncodingFlag',
#  'https://docs.python.org/library/sqlite3.html#sqlite3.version_info',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.interactive',
#  'https://docs.python.org/library/collections.abc.html#collections.abc.Buffer',
#  'https://docs.python.org/c-api/import.html#c.PyImport_ImportModuleNoBlock',
#  'https://docs.python.org/library/tarfile.html#module-tarfile',
#  'https://docs.python.org/library/symtable.html#symtable.Class.get_methods',
#  'https://docs.python.org/library/sysconfig.html#module-sysconfig',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.legacy_windows_stdio',
#  'https://docs.python.org/library/importlib.resources.abc.html#module-importlib.resources.abc',
#  'https://docs.python.org/c-api/init.html#c.Py_GetExecPrefix',
#  'https://docs.python.org/library/threading.html#module-threading',
#  'https://docs.python.org/c-api/init.html#c.Py_GetProgramFullPath',
#  'https://docs.python.org/library/collections.abc.html#collections.abc.ByteString',
#  'https://docs.python.org/library/pkgutil.html#pkgutil.find_loader',
#  'https://docs.python.org/c-api/init.html#c.Py_GetPythonHome',
#  'https://docs.python.org/c-api/slice.html#c.PySlice_AdjustIndices',
#  'https://docs.python.org/library/datetime.html#datetime.datetime.utcnow',
#  'https://docs.python.org#pending-removal-in-python-3-14',
#  'https://docs.python.org/c-api/slice.html#c.PySlice_GetIndicesEx',
#  'https://docs.python.org/library/xml.etree.elementtree.html#xml.etree.ElementTree.Element',
#  'https://docs.python.org/library/sys.html#sys._enablelegacywindowsfsencoding',
#  'https://docs.python.org/library/sys.html#sys.base_prefix',
#  'https://docs.python.org/c-api/unicode.html#c.Py_UCS4',
#  'https://docs.python.org/library/sys.html#sys.executable',
#  'https://docs.python.org/reference/expressions.html#is',
#  'https://docs.python.org/library/gettext.html#module-gettext',
#  'https://docs.python.org/c-api/init.html#c.Py_InspectFlag',
#  'https://docs.python.org/library/asyncio-policy.html#asyncio.AbstractEventLoopPolicy.get_child_watcher',
#  'https://docs.python.org/library/sysconfig.html#sysconfig.is_python_build',
#  'https://docs.python.org/library/sys.html#sys.exec_prefix',
#  'https://docs.python.org/c-api/init.html#c.Py_VerboseFlag',
#  'https://docs.python.org/reference/datamodel.html#module.__loader__',
#  'https://docs.python.org/library/functions.html#complex',
#  'https://docs.python.org/library/importlib.resources.abc.html#importlib.resources.abc.TraversableResources',
#  'https://docs.python.org/library/zipimport.html#zipimport.zipimporter.load_module',
#  'https://docs.python.org/c-api/init.html#c.Py_OptimizeFlag',
#  'https://docs.python.org/reference/expressions.html#in',
#  'https://docs.python.org/library/wave.html#wave.Wave_read',
#  'https://docs.python.org/c-api/exceptions.html#c.PyErr_SetRaisedException',
#  'https://docs.python.org/faq/installed.html',
#  'https://docs.python.org#id1',
#  'https://docs.python.org/library/email.utils.html#email.utils.localtime',
#  'https://docs.python.org/c-api/weakref.html#c.PyWeakref_GetRef',
#  'https://docs.python.org/library/sqlite3.html#sqlite3-placeholders',
#  'https://docs.python.org/library/urllib.request.html#urllib.request.urlopen',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.parser_debug',
#  'https://docs.python.org/reference/expressions.html#or',
#  'https://docs.python.org/library/urllib.parse.html#module-urllib.parse',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.program_name',
#  'https://docs.python.org/library/typing.html#typing.Text',
#  'https://docs.python.org/c-api/init.html#c.PyThread_tss_free',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig',
#  'https://docs.python.org/c-api/unicode.html#c.Py_UNICODE',
#  'https://docs.python.org/c-api/init.html#c.PyThread_tss_delete',
#  'https://docs.python.org/library/os.path.html#os.path.isreserved',
#  'https://docs.python.org/library/wave.html#wave.Wave_read.getmarkers',
#  'https://docs.python.org/library/sys.html#module-sys',
#  'https://docs.python.org/reference/compound_stmts.html#for',
#  'https://docs.python.org/library/asyncio-policy.html#asyncio.set_child_watcher',
#  'https://docs.python.org/library/array.html#module-array',
#  'https://docs.python.org/index.html',
#  'https://docs.python.org/library/itertools.html#module-itertools',
#  'https://docs.python.org/library/logging.html#logging.warning',
#  'https://docs.python.org/library/argparse.html#module-argparse',
#  'https://docs.python.org/c-api/init.html#c.Py_DebugFlag',
#  'https://docs.python.org/library/email.html#module-email',
#  'https://docs.python.org/library/urllib.parse.html#urllib.parse.urlparse',
#  'https://docs.python.org/library/pty.html#module-pty',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.use_hash_seed',
#  'https://docs.python.org/library/functions.html#float',
#  'https://docs.python.org#id2',
#  'https://docs.python.org/library/pty.html#pty.openpty',
#  'https://docs.python.org/library/pathlib.html#pathlib.PurePath.relative_to',
#  'https://docs.python.org/c-api/init.html#c.Py_NoUserSiteDirectory',
#  'https://docs.python.org/library/sqlite3.html#sqlite3.version',
#  'https://docs.python.org/library/threading.html#threading.Thread.daemon',
#  'https://docs.python.org/c-api/exceptions.html#c.PyErr_DisplayException',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.optimization_level',
#  'https://docs.python.org/library/asyncio-policy.html#asyncio.AbstractChildWatcher',
#  'https://docs.python.org/c-api/exceptions.html#c.PyErr_Fetch',
#  'https://docs.python.org/c-api/init.html#c.Py_BytesWarningFlag',
#  'https://docs.python.org/c-api/sys.html#c.PyOS_AfterFork_Child',
#  'https://docs.python.org/library/re.html#module-re',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.home',
#  'https://docs.python.org/c-api/exceptions.html#c.PyErr_GetRaisedException',
#  'https://docs.python.org/c-api/init_config.html#c.Py_PreInitialize',
#  'https://docs.python.org/library/zipimport.html#zipimport.zipimporter.exec_module',
#  'https://docs.python.org/c-api/init.html#c.PyThread_delete_key_value',
#  'https://docs.python.org/library/http.server.html#module-http.server',
#  'https://docs.python.org/library/typing.html#typing.TypedDict',
#  'https://docs.python.org/library/ssl.html#module-ssl',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.bytes_warning',
#  'https://docs.python.org/library/wave.html#module-wave',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.write_bytecode',
#  'https://docs.python.org/c-api/sys.html#c.PySys_ResetWarnOptions',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.quiet',
#  'https://docs.python.org/library/asyncio-policy.html#asyncio.AbstractEventLoopPolicy.set_child_watcher',
#  'https://docs.python.org/library/threading.html#threading.active_count',
#  'https://docs.python.org/library/xml.etree.elementtree.html#module-xml.etree.ElementTree',
#  'https://docs.python.org/c-api/init.html#c.Py_InteractiveFlag',
#  'https://docs.python.org/library/typing.html#typing.NamedTuple',
#  'https://docs.python.org/c-api/init.html#c.PyThread_tss_alloc',
#  'https://docs.python.org/library/ctypes.html#module-ctypes',
#  'https://docs.python.org/library/multiprocessing.html#multiprocessing.set_start_method',
#  'https://docs.python.org/reference/datamodel.html#module.__package__',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.argv',
#  'https://docs.python.org/library/urllib.html#module-urllib',
#  'https://docs.python.org/library/threading.html#threading.Thread.name',
#  'https://docs.python.org/c-api/init.html#c.PyThread_delete_key',
#  'https://docs.python.org/c-api/init_config.html#c.PyPreConfig.utf8_mode',
#  'https://docs.python.org/library/wave.html#wave.Wave_write',
#  'https://docs.python.org/library/importlib.metadata.html#module-importlib.metadata',
#  'https://docs.python.org/c-api/sys.html#c.PyOS_AfterFork',
#  'https://docs.python.org/c-api/weakref.html#c.PyWeakref_GET_OBJECT',
#  'https://docs.python.org/c-api/exceptions.html#c.PyErr_Restore',
#  'https://docs.python.org/library/locale.html#module-locale',
#  'https://docs.python.org/library/builtins.html#module-builtins',
#  'https://docs.python.org/library/threading.html#threading.Event.is_set',
#  'https://docs.python.org/c-api/init.html#c.Py_GetProgramName',
#  'https://docs.python.org/library/calendar.html#calendar.JANUARY',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.filesystem_errors',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.inspect',
#  'https://docs.python.org/c-api/codec.html#c.PyCodec_Decode',
#  'https://docs.python.org/library/threading.html#threading.Thread.setName',
#  'https://docs.python.org/reference/compound_stmts.html#else',
#  'https://docs.python.org/library/exceptions.html#DeprecationWarning',
#  'https://docs.python.org/library/os.html#module-os',
#  'https://docs.python.org/library/urllib.request.html#module-urllib.request',
#  'https://docs.python.org/using/cmdline.html#envvar-PYTHONHOME',
#  'https://docs.python.org/library/pathlib.html#pathlib.PurePath.is_reserved',
#  'https://docs.python.org/library/symtable.html#module-symtable',
#  'https://docs.python.org/library/shutil.html#shutil.rmtree',
#  'https://docs.python.org/library/typing.html#module-typing',
#  'https://docs.python.org/library/calendar.html#module-calendar',
#  'https://docs.python.org/c-api/init.html#c.Py_NoSiteFlag',
#  'https://docs.python.org/c-api/init.html#c.Py_LegacyWindowsStdioFlag',
#  'https://docs.python.org/c-api/init.html#c.Py_UnbufferedStdioFlag',
#  'https://docs.python.org/c-api/init.html#c.Py_FrozenFlag',
#  'https://docs.python.org/library/shutil.html#module-shutil',
#  'https://docs.python.org/library/locale.html#locale.setlocale',
#  'https://docs.python.org/reference/expressions.html#and',
#  'https://docs.python.org/library/sys.html#sys.path',
#  'https://docs.python.org/library/unittest.html#unittest.IsolatedAsyncioTestCase',
#  'https://docs.python.org/library/os.html#os.register_at_fork',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.filesystem_encoding',
#  'https://docs.python.org/library/exceptions.html#RuntimeError',
#  'https://docs.python.org/library/importlib.resources.abc.html#importlib.resources.abc.Traversable',
#  'https://docs.python.org/reference/datamodel.html#codeobject.co_lines',
#  'https://docs.python.org/library/multiprocessing.html#multiprocessing-start-methods',
#  'https://docs.python.org/c-api/init.html#c.Py_GetPrefix',
#  'https://docs.python.org/c-api/unicode.html#c.PyUnicode_READY',
#  'https://docs.python.org/library/mailbox.html#module-mailbox',
#  'https://docs.python.org/library/asyncio-eventloop.html#asyncio.get_event_loop',
#  'https://docs.python.org/library/logging.html#module-logging',
#  'https://docs.python.org/c-api/init.html#c.Py_QuietFlag',
#  'https://docs.python.org/c-api/weakref.html#c.PyWeakref_GetObject',
#  'https://docs.python.org/library/pkgutil.html#module-pkgutil',
#  'https://docs.python.org/c-api/dict.html#c.PyDictObject',
#  'https://docs.python.org/library/importlib.html#module-importlib.abc',
#  'https://docs.python.org/c-api/init.html#c.PyThread_ReInitTLS',
#  'https://docs.python.org/library/datetime.html#datetime.datetime.utcfromtimestamp',
#  'https://docs.python.org/library/calendar.html#calendar.FEBRUARY',
#  'https://docs.python.org/library/datetime.html#module-datetime',
#  'https://docs.python.org/c-api/init_config.html#c.PyConfig.user_site_directory',
#  'https://docs.python.org#deprecations',
#  'https://docs.python.org/library/ast.html#ast.Constant',
#  'https://docs.python.org/c-api/exceptions.html#c.PyErr_NormalizeException',
#  'https://docs.python.org/library/sqlite3.html#sqlite3.Cursor.executemany',
#  'https://docs.python.org/whatsnew/3.0.html',
#  'https://docs.python.org/whatsnew/3.15.html',
#  'https://docs.python.org/whatsnew/2.7.html',
#  'https://docs.python.org/3/index.html',
#  'https://docs.python.org/argparse.html#argparse-tutorial',
#  'https://docs.python.org/free-threading-python.html#freethreading-python-howto',
#  'https://docs.python.org/isolating-extensions.html#isolating-extensions-howto',
#  'https://docs.python.org/cporting.html#cporting-howto',
#  'https://docs.python.org/timerfd.html#timerfd-howto',
#  'https://docs.python.org/descriptor.html#descriptorhowto',
#  'https://docs.python.org/perf_profiling.html#perf-profiling',
#  'https://docs.python.org/unicode.html#unicode-howto',
#  'https://docs.python.org/ipaddress.html#ipaddress-howto',
#  'https://docs.python.org/annotations.html#annotations-howto',
#  'https://docs.python.org#python-howtos',
#  'https://docs.python.org/sockets.html#socket-howto',
#  'https://docs.python.org/instrumentation.html#instrumentation',
#  'https://docs.python.org/functional.html#functional-howto',
#  'https://docs.python.org/logging.html#logging-howto',
#  'https://docs.python.org/curses.html#curses-howto',
#  'https://docs.python.org/gdb_helpers.html#gdb',
#  'https://docs.python.org/cporting.html',
#  'https://docs.python.org/regex.html#regex-howto',
#  'https://docs.python.org/sorting.html#sortinghowto',
#  'https://docs.python.org/urllib2.html#urllib-howto',
#  'https://docs.python.org/enum.html#enum-howto',
#  'https://docs.python.org/free-threading-extensions.html#freethreading-extensions-howto',
#  'https://docs.python.org/logging-cookbook.html#logging-cookbook',
#  'https://docs.python.org/mro.html#python-2-3-mro',
#  'https://docs.python.org/3/library/index.html']

# %%
https://scikit-learn.org/stable/user_guide.html

# %%
from random import sample

# %%
kubernetes_url=sitemap_search("https://kubernetes.io", target_lang="fr")
python_url = sitemap_search("https://docs.python.org")
js_urls = sitemap_search("https://developer.mozilla.org", target_lang="fr")

# %%
site_list = ["docs.docker.com", "docs.djangoproject.com", "kubernetes.io", "docs.pytorch.org/docs/stable/index.html", "nextjs.org/sitemap.xml", "scikit-learn.org/stable/"]
url_list = []
for site in site_list:
    urls = sitemap_search(f"https://{site}", max_sitemaps=10)
    try :
        samples = sample(urls, 10)
    except ValueError as e:
        print("Error caught, not sampling")
        samples = urls

    url_list.extend(urls)
url_list
# Out:
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://docs.djangoproject.com/sitemap_news.xml
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://docs.djangoproject.com/sitemap_index.xml
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://docs.djangoproject.com/sitemap
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://docs.djangoproject.com/sitemap.xml.gz
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://docs.pytorch.org/sitemap_news.xml
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://docs.pytorch.org/sitemap_news.xml
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://docs.pytorch.org/sitemap_index.xml
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://docs.pytorch.org/sitemap_index.xml
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://docs.pytorch.org/sitemap
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://docs.pytorch.org/sitemap.xml.gz
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://docs.pytorch.org/sitemap.xml.gz
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://docs.pytorch.org/sitemap.xml
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://docs.pytorch.org/sitemap.xml
# Error caught, not sampling
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://scikit-learn.org/robots.txt
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://scikit-learn.org/sitemap_news.xml
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://scikit-learn.org/sitemap_news.xml
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://scikit-learn.org/sitemap_index.xml
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://scikit-learn.org/sitemap_index.xml
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://scikit-learn.org/sitemap
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://scikit-learn.org/sitemap.xml.gz
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://scikit-learn.org/sitemap.xml.gz
# ERROR:trafilatura.downloads:not a 200 response: 404 for URL https://scikit-learn.org/sitemap.xml
# WARNING:trafilatura.sitemaps:not a valid XML sitemap: https://scikit-learn.org/sitemap.xml
# Error caught, not sampling
# ['https://docs.docker.com/reference/api/hub/latest/',
#  'https://docs.docker.com/get-started/introduction/get-docker-desktop/',
#  'https://docs.docker.com/get-started/docker-concepts/running-containers/publishing-ports/',
#  'https://docs.docker.com/get-started/docker-concepts/building-images/understanding-image-layers/',
#  'https://docs.docker.com/get-started/introduction/develop-with-containers/',
#  'https://docs.docker.com/reference/api/hub/latest-changelog/',
#  'https://docs.docker.com/get-started/docker-concepts/running-containers/overriding-container-defaults/',
#  'https://docs.docker.com/get-started/docker-concepts/building-images/writing-a-dockerfile/',
#  'https://docs.docker.com/get-started/introduction/build-and-push-first-image/',
#  'https://docs.docker.com/get-started/docker-concepts/building-images/build-tag-and-publish-an-image/',
#  'https://docs.docker.com/reference/api/hub/deprecated/',
#  'https://docs.docker.com/get-started/docker-concepts/running-containers/persisting-container-data/',
#  'https://docs.docker.com/reference/api/hub/dvp/',
#  'https://docs.docker.com/get-started/docker-concepts/running-containers/sharing-local-files/',
#  'https://docs.docker.com/get-started/docker-concepts/building-images/using-the-build-cache/',
#  'https://docs.docker.com/get-started/introduction/whats-next/',
#  'https://docs.docker.com/guides/golang/build-images/',
#  'https://docs.docker.com/guides/rust/build-images/',
#  'https://docs.docker.com/guides/cpp/multistage/',
#  'https://docs.docker.com/get-started/docker-concepts/running-containers/multi-container-applications/',
#  'https://docs.docker.com/get-started/docker-concepts/building-images/multi-stage-builds/',
#  'https://docs.docker.com/extensions/extensions-sdk/extensions/labels/',
#  'https://docs.docker.com/admin/',
#  'https://docs.docker.com/ai/gordon/',
#  'https://docs.docker.com/guides/cpp/containerize/',
#  'https://docs.docker.com/desktop/settings-and-maintenance/settings/',
#  'https://docs.docker.com/desktop/troubleshoot-and-support/troubleshoot/topics/',
#  'https://docs.docker.com/guides/admin-set-up/comms-and-info-gathering/',
#  'https://docs.docker.com/engine/cli/completion/',
#  'https://docs.docker.com/guides/angular/containerize/',
#  'https://docs.docker.com/guides/reactjs/containerize/',
#  'https://docs.docker.com/guides/bun/containerize/',
#  'https://docs.docker.com/guides/deno/containerize/',
#  'https://docs.docker.com/guides/dotnet/containerize/',
#  'https://docs.docker.com/guides/genai-pdf-bot/containerize/',
#  'https://docs.docker.com/guides/java/containerize/',
#  'https://docs.docker.com/guides/nodejs/containerize/',
#  'https://docs.docker.com/guides/php/containerize/',
#  'https://docs.docker.com/guides/python/containerize/',
#  'https://docs.docker.com/guides/r/containerize/',
#  'https://docs.docker.com/guides/rag-ollama/containerize/',
#  'https://docs.docker.com/guides/ruby/containerize/',
#  'https://docs.docker.com/desktop/use-desktop/container/',
#  'https://docs.docker.com/contribute/',
#  'https://docs.docker.com/extensions/extensions-sdk/build/minimal-frontend-extension/',
#  'https://docs.docker.com/engine/swarm/swarm-tutorial/create-swarm/',
#  'https://docs.docker.com/accounts/create-account/',
#  'https://docs.docker.com/admin/organization/orgs/',
#  'https://docs.docker.com/guides/rag-ollama/develop/',
#  'https://docs.docker.com/build/concepts/overview/',
#  'https://docs.docker.com/desktop/',
#  'https://docs.docker.com/engine/',
#  'https://docs.docker.com/compose/support-and-feedback/faq/',
#  'https://docs.docker.com/admin/faqs/general-faqs/',
#  'https://docs.docker.com/desktop/troubleshoot-and-support/faqs/general/',
#  'https://docs.docker.com/security/faqs/general/',
#  'https://docs.docker.com/security/faqs/single-sign-on/faqs/',
#  'https://docs.docker.com/security/for-developers/2fa/new-recovery-code/',
#  'https://docs.docker.com/get-started/get-docker/',
#  'https://docs.docker.com/contribute/style/grammar/',
#  'https://docs.docker.com/extensions/extensions-sdk/design/design-guidelines/',
#  'https://docs.docker.com/compose/intro/compose-application-model/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/enhanced-container-isolation/how-eci-works/',
#  'https://docs.docker.com/engine/swarm/how-swarm-mode-works/nodes/',
#  'https://docs.docker.com/copilot/install/',
#  'https://docs.docker.com/engine/install/',
#  'https://docs.docker.com/scout/install/',
#  'https://docs.docker.com/build/bake/introduction/',
#  'https://docs.docker.com/desktop/setup/install/mac-install/',
#  'https://docs.docker.com/extensions/marketplace/',
#  'https://docs.docker.com/compose/how-tos/multiple-compose-files/merge/',
#  'https://docs.docker.com/desktop/setup/install/enterprise-deployment/msi-install-and-configure/',
#  'https://docs.docker.com/build/building/multi-stage/',
#  'https://docs.docker.com/admin/organization/',
#  'https://docs.docker.com/engine/network/packet-filtering-firewalls/',
#  'https://docs.docker.com/compose/install/linux/',
#  'https://docs.docker.com/guides/frameworks/laravel/prerequisites/',
#  'https://docs.docker.com/docker-hub/usage/pulls/',
#  'https://docs.docker.com/docker-hub/quickstart/',
#  'https://docs.docker.com/compose/releases/release-notes/',
#  'https://docs.docker.com/engine/security/rootless/',
#  'https://docs.docker.com/guides/golang/run-containers/',
#  'https://docs.docker.com/guides/rust/run-containers/',
#  'https://docs.docker.com/reference/api/engine/sdk/',
#  'https://docs.docker.com/docker-hub/image-library/search/',
#  'https://docs.docker.com/engine/storage/drivers/select-storage-driver/',
#  'https://docs.docker.com/compose/how-tos/environment-variables/set-environment-variables/',
#  'https://docs.docker.com/docker-hub/repos/manage/builds/setup/',
#  'https://docs.docker.com/guides/admin-user-management/setup/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/settings-management/',
#  'https://docs.docker.com/build-cloud/setup/',
#  'https://docs.docker.com/security/for-admins/single-sign-on/',
#  'https://docs.docker.com/compose/how-tos/project-name/',
#  'https://docs.docker.com/engine/containers/start-containers-automatically/',
#  'https://docs.docker.com/engine/daemon/start/',
#  'https://docs.docker.com/subscription/details/',
#  'https://docs.docker.com/docker-hub/repos/manage/hub-images/tags/',
#  'https://docs.docker.com/extensions/extensions-sdk/dev/test-debug/',
#  'https://docs.docker.com/extensions/extensions-sdk/process/',
#  'https://docs.docker.com/desktop/troubleshoot-and-support/troubleshoot/',
#  'https://docs.docker.com/desktop/setup/install/linux/ubuntu/',
#  'https://docs.docker.com/engine/install/ubuntu/',
#  'https://docs.docker.com/guides/go-prometheus-monitoring/application/',
#  'https://docs.docker.com/compose/bridge/usage/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/settings-management/configure-json-file/',
#  'https://docs.docker.com/reference/compose-file/version-and-name/',
#  'https://docs.docker.com/engine/storage/volumes/',
#  'https://docs.docker.com/get-started/docker-concepts/the-basics/what-is-a-container/',
#  'https://docs.docker.com/guides/docker-build-cloud/why/',
#  'https://docs.docker.com/guides/docker-compose/why/',
#  'https://docs.docker.com/guides/docker-scout/why/',
#  'https://docs.docker.com/guides/testcontainers-cloud/why/',
#  'https://docs.docker.com/docker-hub/repos/manage/hub-images/immutable-tags/',
#  'https://docs.docker.com/docker-hub/repos/manage/hub-images/manage/',
#  'https://docs.docker.com/subscription/setup/',
#  'https://docs.docker.com/docker-hub/image-library/trusted-content/',
#  'https://docs.docker.com/subscription/scale/',
#  'https://docs.docker.com/engine/swarm/swarm-tutorial/add-nodes/',
#  'https://docs.docker.com/billing/payment-method/',
#  'https://docs.docker.com/guides/ruby/configure-github-actions/',
#  'https://docs.docker.com/desktop/settings-and-maintenance/backup-and-restore/',
#  'https://docs.docker.com/billing/',
#  'https://docs.docker.com/engine/storage/bind-mounts/',
#  'https://docs.docker.com/get-started/docker-concepts/building-images/',
#  'https://docs.docker.com/admin/company/',
#  'https://docs.docker.com/security/faqs/containers/',
#  'https://docs.docker.com/guides/go-prometheus-monitoring/containerize/',
#  'https://docs.docker.com/extensions/extensions-sdk/dev/continuous-integration/',
#  'https://docs.docker.com/docker-hub/repos/create/',
#  'https://docs.docker.com/extensions/extensions-sdk/build/frontend-extension-tutorial/',
#  'https://docs.docker.com/compose/bridge/customize/',
#  'https://docs.docker.com/desktop/setup/install/linux/debian/',
#  'https://docs.docker.com/engine/install/debian/',
#  'https://docs.docker.com/guides/docker-scout/demo/',
#  'https://docs.docker.com/guides/docker-build-cloud/dev/',
#  'https://docs.docker.com/guides/docker-compose/setup/',
#  'https://docs.docker.com/guides/bun/develop/',
#  'https://docs.docker.com/guides/cpp/develop/',
#  'https://docs.docker.com/guides/deno/develop/',
#  'https://docs.docker.com/guides/dotnet/develop/',
#  'https://docs.docker.com/guides/genai-pdf-bot/develop/',
#  'https://docs.docker.com/guides/golang/develop/',
#  'https://docs.docker.com/guides/java/develop/',
#  'https://docs.docker.com/guides/nodejs/develop/',
#  'https://docs.docker.com/guides/php/develop/',
#  'https://docs.docker.com/guides/python/develop/',
#  'https://docs.docker.com/guides/r/develop/',
#  'https://docs.docker.com/guides/rust/develop/',
#  'https://docs.docker.com/build/',
#  'https://docs.docker.com/build-cloud/',
#  'https://docs.docker.com/extensions/extensions-sdk/design/design-principles/',
#  'https://docs.docker.com/ai/model-runner/',
#  'https://docs.docker.com/build/concepts/dockerfile/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/enhanced-container-isolation/',
#  'https://docs.docker.com/compose/how-tos/environment-variables/envvars-precedence/',
#  'https://docs.docker.com/compose/how-tos/multiple-compose-files/extends/',
#  'https://docs.docker.com/guides/admin-set-up/finalize-plans-and-setup/',
#  'https://docs.docker.com/contribute/style/formatting/',
#  'https://docs.docker.com/desktop/troubleshoot-and-support/support/',
#  'https://docs.docker.com/compose/support-and-feedback/feedback/',
#  'https://docs.docker.com/engine/swarm/how-swarm-mode-works/services/',
#  'https://docs.docker.com/desktop/use-desktop/images/',
#  'https://docs.docker.com/compose/install/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/enhanced-container-isolation/features-benefits/',
#  'https://docs.docker.com/guides/frameworks/laravel/production-setup/',
#  'https://docs.docker.com/docker-hub/image-library/',
#  'https://docs.docker.com/docker-hub/repos/manage/builds/link-source/',
#  'https://docs.docker.com/desktop/troubleshoot-and-support/faqs/macfaqs/',
#  'https://docs.docker.com/desktop/setup/install/mac-permission-requirements/',
#  'https://docs.docker.com/accounts/manage-account/',
#  'https://docs.docker.com/subscription/manage-seats/',
#  'https://docs.docker.com/compose/releases/migrate/',
#  'https://docs.docker.com/engine/network/drivers/',
#  'https://docs.docker.com/extensions/non-marketplace/',
#  'https://docs.docker.com/admin/organization/onboard/',
#  'https://docs.docker.com/guides/admin-user-management/onboard/',
#  'https://docs.docker.com/admin/faqs/organization-faqs/',
#  'https://docs.docker.com/get-started/workshop/02_our_app/',
#  'https://docs.docker.com/desktop/setup/install/enterprise-deployment/pkg-install-and-configure/',
#  'https://docs.docker.com/security/for-admins/provisioning/',
#  'https://docs.docker.com/engine/cli/proxy/',
#  'https://docs.docker.com/extensions/extensions-sdk/quickstart/',
#  'https://docs.docker.com/scout/quickstart/',
#  'https://docs.docker.com/security/for-developers/2fa/recover-hub-account/',
#  'https://docs.docker.com/docker-hub/repos/',
#  'https://docs.docker.com/engine/containers/multi-service_container/',
#  'https://docs.docker.com/reference/compose-file/services/',
#  'https://docs.docker.com/guides/testcontainers-cloud/demo-local/',
#  'https://docs.docker.com/docker-hub/repos/manage/hub-images/oci-artifacts/',
#  'https://docs.docker.com/compose/install/standalone/',
#  'https://docs.docker.com/engine/storage/',
#  'https://docs.docker.com/build/bake/targets/',
#  'https://docs.docker.com/build-cloud/usage/',
#  'https://docs.docker.com/copilot/usage/',
#  'https://docs.docker.com/engine/daemon/ipv6/',
#  'https://docs.docker.com/compose/how-tos/lifecycle/',
#  'https://docs.docker.com/compose/how-tos/profiles/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/settings-management/configure-admin-console/',
#  'https://docs.docker.com/extensions/extensions-sdk/extensions/validate/',
#  'https://docs.docker.com/build/building/variables/',
#  'https://docs.docker.com/get-started/docker-concepts/the-basics/what-is-an-image/',
#  'https://docs.docker.com/get-started/docker-overview/',
#  'https://docs.docker.com/compose/intro/features-uses/',
#  'https://docs.docker.com/compose/bridge/advanced-integration/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/enhanced-container-isolation/config/',
#  'https://docs.docker.com/docker-hub/repos/manage/builds/automated-testing/',
#  'https://docs.docker.com/build/checks/',
#  'https://docs.docker.com/build/concepts/context/',
#  'https://docs.docker.com/subscription/change/',
#  'https://docs.docker.com/extensions/extensions-sdk/dev/usage/',
#  'https://docs.docker.com/guides/docker-compose/common-questions/',
#  'https://docs.docker.com/admin/faqs/company-faqs/',
#  'https://docs.docker.com/extensions/private-marketplace/',
#  'https://docs.docker.com/guides/testcontainers-cloud/demo-ci/',
#  'https://docs.docker.com/guides/go-prometheus-monitoring/compose/',
#  'https://docs.docker.com/build-cloud/ci/',
#  'https://docs.docker.com/compose/how-tos/startup-order/',
#  'https://docs.docker.com/engine/daemon/proxy/',
#  'https://docs.docker.com/accounts/deactivate-user-account/',
#  'https://docs.docker.com/guides/docker-build-cloud/ci/',
#  'https://docs.docker.com/engine/swarm/swarm-tutorial/deploy-service/',
#  'https://docs.docker.com/desktop/setup/install/enterprise-deployment/use-intune/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/settings-management/compliance-reporting/',
#  'https://docs.docker.com/guides/angular/develop/',
#  'https://docs.docker.com/guides/reactjs/develop/',
#  'https://docs.docker.com/security/for-developers/2fa/disable-2fa/',
#  'https://docs.docker.com/accounts/',
#  'https://docs.docker.com/compose/',
#  'https://docs.docker.com/docker-hub/',
#  'https://docs.docker.com/security/for-admins/enforce-sign-in/',
#  'https://docs.docker.com/copilot/examples/',
#  'https://docs.docker.com/desktop/use-desktop/',
#  'https://docs.docker.com/desktop/setup/install/linux/fedora/',
#  'https://docs.docker.com/engine/cli/filter/',
#  'https://docs.docker.com/compose/intro/history/',
#  'https://docs.docker.com/build/bake/inheritance/',
#  'https://docs.docker.com/get-started/introduction/',
#  'https://docs.docker.com/desktop/troubleshoot-and-support/troubleshoot/known-issues/',
#  'https://docs.docker.com/guides/frameworks/laravel/development-setup/',
#  'https://docs.docker.com/admin/organization/members/',
#  'https://docs.docker.com/ai/mcp-catalog-and-toolkit/',
#  'https://docs.docker.com/guides/admin-user-management/audit-and-monitor/',
#  'https://docs.docker.com/security/faqs/networking-and-vms/',
#  'https://docs.docker.com/desktop/features/networking/',
#  'https://docs.docker.com/engine/network/',
#  'https://docs.docker.com/reference/compose-file/networks/',
#  'https://docs.docker.com/extensions/extensions-sdk/extensions/DISTRIBUTION/',
#  'https://docs.docker.com/get-started/workshop/03_updating_app/',
#  'https://docs.docker.com/compose/how-tos/environment-variables/envvars/',
#  'https://docs.docker.com/docker-hub/repos/manage/hub-images/push/',
#  'https://docs.docker.com/compose/gettingstarted/',
#  'https://docs.docker.com/contribute/style/recommended-words/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/registry-access-management/',
#  'https://docs.docker.com/engine/containers/resource_constraints/',
#  'https://docs.docker.com/engine/install/rhel/',
#  'https://docs.docker.com/guides/dotnet/run-tests/',
#  'https://docs.docker.com/guides/golang/run-tests/',
#  'https://docs.docker.com/guides/java/run-tests/',
#  'https://docs.docker.com/guides/nodejs/run-tests/',
#  'https://docs.docker.com/guides/php/run-tests/',
#  'https://docs.docker.com/compose/support-and-feedback/samples-for-compose/',
#  'https://docs.docker.com/security/for-admins/provisioning/scim/',
#  'https://docs.docker.com/build/building/secrets/',
#  'https://docs.docker.com/guides/docker-scout/s3c/',
#  'https://docs.docker.com/contribute/file-conventions/',
#  'https://docs.docker.com/guides/admin-set-up/testing/',
#  'https://docs.docker.com/engine/storage/tmpfs/',
#  'https://docs.docker.com/billing/details/',
#  'https://docs.docker.com/docker-hub/usage/',
#  'https://docs.docker.com/desktop/setup/vm-vdi/',
#  'https://docs.docker.com/desktop/use-desktop/volumes/',
#  'https://docs.docker.com/get-started/docker-concepts/the-basics/what-is-a-registry/',
#  'https://docs.docker.com/desktop/setup/install/windows-install/',
#  'https://docs.docker.com/desktop/troubleshoot-and-support/faqs/windowsfaqs/',
#  'https://docs.docker.com/docker-hub/repos/archive/',
#  'https://docs.docker.com/admin/organization/convert-account/',
#  'https://docs.docker.com/billing/3d-secure/',
#  'https://docs.docker.com/docker-hub/repos/manage/builds/advanced/',
#  'https://docs.docker.com/build/builders/',
#  'https://docs.docker.com/desktop/use-desktop/builds/',
#  'https://docs.docker.com/guides/docker-build-cloud/common-questions/',
#  'https://docs.docker.com/guides/testcontainers-cloud/common-questions/',
#  'https://docs.docker.com/guides/frameworks/laravel/common-questions/',
#  'https://docs.docker.com/guides/bun/configure-ci-cd/',
#  'https://docs.docker.com/guides/cpp/configure-ci-cd/',
#  'https://docs.docker.com/guides/deno/configure-ci-cd/',
#  'https://docs.docker.com/guides/dotnet/configure-ci-cd/',
#  'https://docs.docker.com/guides/golang/configure-ci-cd/',
#  'https://docs.docker.com/guides/java/configure-ci-cd/',
#  'https://docs.docker.com/guides/nodejs/configure-ci-cd/',
#  'https://docs.docker.com/guides/php/configure-ci-cd/',
#  'https://docs.docker.com/guides/python/configure-ci-cd/',
#  'https://docs.docker.com/guides/r/configure-ci-cd/',
#  'https://docs.docker.com/guides/rust/configure-ci-cd/',
#  'https://docs.docker.com/admin/organization/manage-a-team/',
#  'https://docs.docker.com/docker-hub/repos/delete/',
#  'https://docs.docker.com/guides/admin-set-up/deploy/',
#  'https://docs.docker.com/desktop/setup/install/enterprise-deployment/use-jamf-pro/',
#  'https://docs.docker.com/guides/go-prometheus-monitoring/develop/',
#  'https://docs.docker.com/guides/ruby/develop/',
#  'https://docs.docker.com/subscription/desktop-license/',
#  'https://docs.docker.com/scout/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/enhanced-container-isolation/faq/',
#  'https://docs.docker.com/engine/install/fedora/',
#  'https://docs.docker.com/engine/cli/formatting/',
#  'https://docs.docker.com/desktop/troubleshoot-and-support/feedback/',
#  'https://docs.docker.com/desktop/features/gpu/',
#  'https://docs.docker.com/security/for-admins/provisioning/group-mapping/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/image-access-management/',
#  'https://docs.docker.com/engine/swarm/swarm-tutorial/inspect-service/',
#  'https://docs.docker.com/compose/how-tos/environment-variables/variable-interpolation/',
#  'https://docs.docker.com/desktop/troubleshoot-and-support/faqs/linuxfaqs/',
#  'https://docs.docker.com/engine/daemon/live-restore/',
#  'https://docs.docker.com/docker-hub/repos/manage/hub-images/move/',
#  'https://docs.docker.com/build/building/multi-platform/',
#  'https://docs.docker.com/build-cloud/optimization/',
#  'https://docs.docker.com/docker-hub/usage/manage/',
#  'https://docs.docker.com/get-started/workshop/04_sharing_app/',
#  'https://docs.docker.com/extensions/extensions-sdk/extensions/',
#  'https://docs.docker.com/docker-hub/repos/manage/information/',
#  'https://docs.docker.com/security/for-admins/roles-and-permissions/',
#  'https://docs.docker.com/guides/angular/run-tests/',
#  'https://docs.docker.com/guides/reactjs/run-tests/',
#  'https://docs.docker.com/security/',
#  'https://docs.docker.com/extensions/settings-feedback/',
#  'https://docs.docker.com/extensions/extensions-sdk/extensions/share/',
#  'https://docs.docker.com/desktop/setup/sign-in/',
#  'https://docs.docker.com/guides/docker-scout/sbom/',
#  'https://docs.docker.com/engine/storage/drivers/',
#  'https://docs.docker.com/contribute/ui/',
#  'https://docs.docker.com/compose/how-tos/environment-variables/',
#  'https://docs.docker.com/build/bake/variables/',
#  'https://docs.docker.com/billing/history/',
#  'https://docs.docker.com/reference/compose-file/volumes/',
#  'https://docs.docker.com/get-started/docker-concepts/the-basics/what-is-docker-compose/',
#  'https://docs.docker.com/desktop/setup/install/windows-permission-requirements/',
#  'https://docs.docker.com/admin/organization/deactivate-account/',
#  'https://docs.docker.com/admin/organization/manage-products/',
#  'https://docs.docker.com/docker-hub/repos/manage/access/',
#  'https://docs.docker.com/admin/organization/activity-logs/',
#  'https://docs.docker.com/extensions/extensions-sdk/architecture/',
#  'https://docs.docker.com/guides/docker-scout/attestations/',
#  'https://docs.docker.com/build/bake/',
#  'https://docs.docker.com/compose/how-tos/environment-variables/best-practices/',
#  'https://docs.docker.com/compose/how-tos/dependent-images/',
#  'https://docs.docker.com/billing/cycle/',
#  'https://docs.docker.com/compose/bridge/',
#  'https://docs.docker.com/reference/compose-file/configs/',
#  'https://docs.docker.com/engine/storage/containerd/',
#  'https://docs.docker.com/copilot/',
#  'https://docs.docker.com/security/for-admins/domain-audit/',
#  'https://docs.docker.com/build/building/export/',
#  'https://docs.docker.com/build/bake/expressions/',
#  'https://docs.docker.com/subscription/faq/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/enhanced-container-isolation/limitations/',
#  'https://docs.docker.com/get-started/workshop/05_persisting_data/',
#  'https://docs.docker.com/docker-hub/repos/settings/',
#  'https://docs.docker.com/extensions/extensions-sdk/extensions/publish/',
#  'https://docs.docker.com/engine/install/raspberry-pi-os/',
#  'https://docs.docker.com/billing/tax-certificate/',
#  'https://docs.docker.com/desktop/use-desktop/resource-saver/',
#  'https://docs.docker.com/engine/containers/runmetrics/',
#  'https://docs.docker.com/engine/swarm/swarm-tutorial/scale-service/',
#  'https://docs.docker.com/docker-hub/service-accounts/',
#  'https://docs.docker.com/subscription/',
#  'https://docs.docker.com/guides/bun/deploy/',
#  'https://docs.docker.com/guides/cpp/deploy/',
#  'https://docs.docker.com/guides/deno/deploy/',
#  'https://docs.docker.com/guides/dotnet/deploy/',
#  'https://docs.docker.com/guides/golang/deploy/',
#  'https://docs.docker.com/guides/java/deploy/',
#  'https://docs.docker.com/guides/nodejs/deploy/',
#  'https://docs.docker.com/guides/php/deploy/',
#  'https://docs.docker.com/guides/python/deploy/',
#  'https://docs.docker.com/guides/r/deploy/',
#  'https://docs.docker.com/guides/ruby/deploy/',
#  'https://docs.docker.com/guides/rust/deploy/',
#  'https://docs.docker.com/desktop/features/usbip/',
#  'https://docs.docker.com/compose/how-tos/file-watch/',
#  'https://docs.docker.com/security/for-admins/domain-management/',
#  'https://docs.docker.com/guides/angular/configure-github-actions/',
#  'https://docs.docker.com/guides/reactjs/configure-github-actions/',
#  'https://docs.docker.com/build/building/best-practices/',
#  'https://docs.docker.com/build/cache/',
#  'https://docs.docker.com/docker-hub/image-library/catalogs/',
#  'https://docs.docker.com/engine/install/centos/',
#  'https://docs.docker.com/engine/daemon/',
#  'https://docs.docker.com/engine/swarm/swarm-tutorial/delete-service/',
#  'https://docs.docker.com/desktop/features/kubernetes/',
#  'https://docs.docker.com/extensions/extensions-sdk/design/',
#  'https://docs.docker.com/extensions/',
#  'https://docs.docker.com/billing/faqs/',
#  'https://docs.docker.com/build/bake/funcs/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/',
#  'https://docs.docker.com/docker-hub/repos/manage/hub-images/',
#  'https://docs.docker.com/desktop/setup/install/linux/',
#  'https://docs.docker.com/admin/organization/general-settings/',
#  'https://docs.docker.com/get-started/workshop/06_bind_mounts/',
#  'https://docs.docker.com/desktop/use-desktop/pause/',
#  'https://docs.docker.com/platform-release-notes/',
#  'https://docs.docker.com/guides/docker-scout/remediation/',
#  'https://docs.docker.com/compose/how-tos/use-secrets/',
#  'https://docs.docker.com/reference/compose-file/secrets/',
#  'https://docs.docker.com/guides/cpp/security/',
#  'https://docs.docker.com/guides/angular/deploy/',
#  'https://docs.docker.com/guides/reactjs/deploy/',
#  'https://docs.docker.com/docker-hub/troubleshoot/',
#  'https://docs.docker.com/contribute/checklist/',
#  'https://docs.docker.com/engine/swarm/swarm-tutorial/rolling-update/',
#  'https://docs.docker.com/build/building/base-images/',
#  'https://docs.docker.com/build/ci/',
#  'https://docs.docker.com/reference/compose-file/fragments/',
#  'https://docs.docker.com/docker-hub/repos/manage/vulnerability-scanning/',
#  'https://docs.docker.com/engine/logging/',
#  'https://docs.docker.com/build/bake/matrices/',
#  'https://docs.docker.com/compose/how-tos/networking/',
#  'https://docs.docker.com/get-started/workshop/07_multi_container/',
#  'https://docs.docker.com/scout/policy/',
#  'https://docs.docker.com/engine/install/sles/',
#  'https://docs.docker.com/desktop/features/synchronized-file-sharing/',
#  'https://docs.docker.com/tcc/',
#  'https://docs.docker.com/engine/install/binaries/',
#  'https://docs.docker.com/desktop/features/containerd/',
#  'https://docs.docker.com/build/bake/contexts/',
#  'https://docs.docker.com/engine/swarm/swarm-tutorial/drain-node/',
#  'https://docs.docker.com/reference/compose-file/extension/',
#  'https://docs.docker.com/scout/integrations/',
#  'https://docs.docker.com/docker-hub/image-library/mirror/',
#  'https://docs.docker.com/get-started/workshop/08_using_compose/',
#  'https://docs.docker.com/engine/security/',
#  'https://docs.docker.com/engine/swarm/',
#  'https://docs.docker.com/compose/how-tos/multiple-compose-files/',
#  'https://docs.docker.com/docker-hub/repos/manage/webhooks/',
#  'https://docs.docker.com/docker-hub/repos/manage/builds/',
#  'https://docs.docker.com/compose/how-tos/gpu-support/',
#  'https://docs.docker.com/build/exporters/',
#  'https://docs.docker.com/reference/compose-file/interpolation/',
#  'https://docs.docker.com/get-started/workshop/09_image_best/',
#  'https://docs.docker.com/engine/install/linux-postinstall/',
#  'https://docs.docker.com/desktop/features/wasm/',
#  'https://docs.docker.com/desktop/setup/allow-list/',
#  'https://docs.docker.com/build/buildkit/',
#  'https://docs.docker.com/desktop/features/desktop-cli/',
#  'https://docs.docker.com/reference/compose-file/merge/',
#  'https://docs.docker.com/get-started/workshop/10_what_next/',
#  'https://docs.docker.com/engine/release-notes/prior-releases/',
#  'https://docs.docker.com/docker-hub/repos/manage/trusted-content/',
#  'https://docs.docker.com/compose/how-tos/production/',
#  'https://docs.docker.com/reference/compose-file/include/',
#  'https://docs.docker.com/compose/how-tos/oci-artifact/',
#  'https://docs.docker.com/desktop/features/vmm/',
#  'https://docs.docker.com/compose/how-tos/model-runner/',
#  'https://docs.docker.com/compose/how-tos/provider-services/',
#  'https://docs.docker.com/build/release-notes/',
#  'https://docs.docker.com/reference/compose-file/profiles/',
#  'https://docs.docker.com/desktop/features/wsl/',
#  'https://docs.docker.com/reference/compose-file/build/',
#  'https://docs.docker.com/reference/compose-file/deploy/',
#  'https://docs.docker.com/reference/compose-file/develop/',
#  'https://docs.docker.com/desktop/uninstall/',
#  'https://docs.docker.com/desktop/cert-revoke-solution/',
#  'https://docs.docker.com/desktop/release-notes/',
#  'https://docs.docker.com/docker-hub/release-notes/',
#  'https://docs.docker.com/reference/samples/dotnet/',
#  'https://docs.docker.com/engine/extend/plugins_authorization/',
#  'https://docs.docker.com/security/for-developers/access-tokens/',
#  'https://docs.docker.com/contribute/components/accordions/',
#  'https://docs.docker.com/extensions/extensions-sdk/build/backend-extension-tutorial/',
#  'https://docs.docker.com/guides/admin-set-up/',
#  'https://docs.docker.com/engine/swarm/admin_guide/',
#  'https://docs.docker.com/tags/admin/',
#  'https://docs.docker.com/scout/deep-dive/advisory-db-sources/',
#  'https://docs.docker.com/tags/ai/',
#  'https://docs.docker.com/reference/samples/ai-ml/',
#  'https://docs.docker.com/security/for-admins/hardened-desktop/air-gapped-containers/',
#  'https://docs.docker.com/engine/daemon/alternative-runtimes/',
#  'https://docs.docker.com/engine/logging/drivers/awslogs/',
#  'https://docs.docker.com/scout/integrations/registry/ecr/',
#  'https://docs.docker.com/build/cache/backends/s3/',
#  'https://docs.docker.com/guides/angular/',
#  'https://docs.docker.com/reference/samples/angular/',
#  'https://docs.docker.com/build/ci/github-actions/annotations/',
#  'https://docs.docker.com/build/metadata/annotations/',
#  'https://docs.docker.com/engine/security/antivirus/',
#  'https://docs.docker.com/tags/app-dev/',
#  'https://docs.docker.com/engine/security/apparmor/',
#  'https://docs.docker.com/desktop/setup/install/linux/archlinux/',
#  'https://docs.docker.com/scout/integrations/registry/artifactory/',
#  'https://docs.docker.com/build/ci/github-actions/attestations/',
#  'https://docs.docker.com/extensions/extensions-sdk/guides/oauth2-flow/',
#  'https://docs.docker.com/engine/security/trust/trust_automation/',
#  'https://docs.docker.com/guides/localstack/',
#  'https://docs.docker.com/build/cache/backends/azblob/',
#  'https://docs.docker.com/scout/integrations/registry/acr/',
#  'https://docs.docker.com/scout/integrations/ci/azure/',
#  'https://docs.docker.com/contribute/components/badges/',
#  'https://docs.docker.com/build/bake/reference/',
#  'https://docs.docker.com/desktop/features/wsl/best-practices/',
#  'https://docs.docker.com/tags/best-practices/',
#  'https://docs.docker.com/engine/network/drivers/bridge/',
#  'https://docs.docker.com/engine/storage/drivers/btrfs-driver/',
#  'https://docs.docker.com/build/metadata/attestations/',
#  'https://docs.docker.com/build/cache/invalidation/',
#  'https://docs.docker.com/reference/build-checks/',
#  'https://docs.docker.com/build/ci/github-actions/checks/',
#  'https://docs.docker.com/build/builders/drivers/',
#  'https://docs.docker.com/build/cache/garbage-collection/',
#  'https://docs.docker.com/extensions/extensions-sdk/extensions/multi-arch/',
#  'https://docs.docker.com/build/ci/github-actions/secrets/',
#  'https://docs.docker.com/build/ci/github-actions/build-summary/',
#  'https://docs.docker.com/build-cloud/builder-settings/',
#  'https://docs.docker.com/guides/compose-bake/',
#  'https://docs.docker.com/build/bake/compose-file/',
#  'https://docs.docker.com/build/ci/github-actions/configure-builder/',
#  'https://docs.docker.com/build/buildkit/toml-configuration/',
#  'https://docs.docker.com/ai/gordon/mcp/built-in-tools/',
#  'https://docs.docker.com/guides/bun/',
#  'https://docs.docker.com/contribute/components/buttons/',
#  'https://docs.docker.com/guides/dotnet/',
#  'https://docs.docker.com/guides/cpp/',
#  'https://docs.docker.com/engine/network/ca-certs/',
#  'https://docs.docker.com/build/ci/github-actions/cache/',
#  'https://docs.docker.com/build/cache/backends/',
#  'https://docs.docker.com/contribute/components/call-outs/',
#  'https://docs.docker.com/contribute/components/cards/',
#  'https://docs.docker.com/scout/integrations/ci/circle-ci/',
#  'https://docs.docker.com/scout/release-notes/cli/',
#  'https://docs.docker.com/tags/cloud-services/',
#  'https://docs.docker.com/reference/samples/cloudflared/',
#  'https://docs.docker.com/contribute/components/code-blocks/',
#  'https://docs.docker.com/engine/daemon/prometheus/',
#  'https://docs.docker.com/guides/docker-scout/common-questions/',
#  'https://docs.docker.com/reference/compose-file/',
#  'https://docs.docker.com/security/for-admins/single-sign-on/configure/',
#  'https://docs.docker.com/build/buildkit/configure/',
#  'https://docs.docker.com/engine/logging/configure/',
#  'https://docs.docker.com/scout/policy/configure/',
#  'https://docs.docker.com/engine/daemon/remote-access/',
#  'https://docs.docker.com/security/for-admins/single-sign-on/connect/',
#  'https://docs.docker.com/reference/build-checks/consistent-instruction-casing/',
#  'https://docs.docker.com/guides/container-supported-development/',
#  'https://docs.docker.com/engine/security/trust/',
#  'https://docs.docker.com/scout/integrations/ci/',
#  'https://docs.docker.com/build/ci/github-actions/copy-image-registries/',
#  'https://docs.docker.com/reference/build-checks/copy-ignored-file/',
#  'https://docs.docker.com/admin/company/new-company/',
#  'https://docs.docker.com/scout/how-tos/create-exceptions-gui/',
#  'https://docs.docker.com/scout/how-tos/create-exceptions-vex/',
#  'https://docs.docker.com/build/buildkit/frontend/',
#  'https://docs.docker.com/desktop/features/wsl/custom-kernels/',
#  'https://docs.docker.com/engine/logging/log_tags/',
#  'https://docs.docker.com/extensions/extensions-sdk/dev/api/dashboard/',
#  'https://docs.docker.com/scout/explore/dashboard/',
#  'https://docs.docker.com/scout/deep-dive/data-handling/',
#  'https://docs.docker.com/tags/data-science/',
#  'https://docs.docker.com/guides/jupyter/',
#  'https://docs.docker.com/tags/databases/',
#  'https://docs.docker.com/engine/security/trust/trust_delegation/',
#  'https://docs.docker.com/guides/deno/',
#  'https://docs.docker.com/engine/swarm/stack-deploy/',
#  'https://docs.docker.com/engine/security/trust/deploying_notary/',
#  'https://docs.docker.com/engine/swarm/services/',
#  'https://docs.docker.com/guides/kube-deploy/',
#  'https://docs.docker.com/guides/swarm-deploy/',
#  'https://docs.docker.com/tags/deploy/',
#  'https://docs.docker.com/guides/orchestration/',
#  'https://docs.docker.com/engine/deprecated/',
#  'https://docs.docker.com/retired/',
#  'https://docs.docker.com/engine/storage/drivers/device-mapper-driver/',
#  'https://docs.docker.com/tags/devops/',
#  'https://docs.docker.com/tags/distributed-systems/',
#  'https://docs.docker.com/reference/samples/django/',
#  'https://docs.docker.com/reference/cli/docker/',
#  'https://docs.docker.com/extensions/extensions-sdk/dev/api/docker/',
#  'https://docs.docker.com/reference/cli/docker/build-legacy/',
#  'https://docs.docker.com/guides/docker-build-cloud/',
#  'https://docs.docker.com/reference/cli/docker/builder/',
#  'https://docs.docker.com/reference/cli/docker/builder/prune/',
#  'https://docs.docker.com/reference/cli/docker/buildx/',
#  'https://docs.docker.com/reference/cli/docker/buildx/bake/',
#  'https://docs.docker.com/reference/cli/docker/buildx/build/',
#  'https://docs.docker.com/reference/cli/docker/buildx/create/',
#  'https://docs.docker.com/reference/cli/docker/buildx/debug/',
#  'https://docs.docker.com/reference/cli/docker/buildx/debug/build/',
#  'https://docs.docker.com/reference/cli/docker/buildx/du/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/export/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/import/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/inspect/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/inspect/attachment/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/logs/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/ls/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/open/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/rm/',
#  'https://docs.docker.com/reference/cli/docker/buildx/history/trace/',
#  'https://docs.docker.com/reference/cli/docker/buildx/imagetools/',
#  'https://docs.docker.com/reference/cli/docker/buildx/imagetools/create/',
#  'https://docs.docker.com/reference/cli/docker/buildx/imagetools/inspect/',
#  'https://docs.docker.com/reference/cli/docker/buildx/inspect/',
#  'https://docs.docker.com/reference/cli/docker/buildx/ls/',
#  'https://docs.docker.com/reference/cli/docker/buildx/prune/',
#  'https://docs.docker.com/reference/cli/docker/buildx/rm/',
#  'https://docs.docker.com/reference/cli/docker/buildx/stop/',
#  'https://docs.docker.com/reference/cli/docker/buildx/use/',
#  'https://docs.docker.com/reference/cli/docker/buildx/version/',
#  'https://docs.docker.com/reference/cli/docker/checkpoint/',
#  'https://docs.docker.com/reference/cli/docker/checkpoint/create/',
#  'https://docs.docker.com/reference/cli/docker/checkpoint/ls/',
#  'https://docs.docker.com/reference/cli/docker/checkpoint/rm/',
#  'https://docs.docker.com/reference/cli/docker/compose/',
#  'https://docs.docker.com/guides/docker-compose/',
#  'https://docs.docker.com/reference/cli/docker/compose/alpha/',
#  'https://docs.docker.com/reference/cli/docker/compose/alpha/dry-run/',
#  'https://docs.docker.com/reference/cli/docker/compose/alpha/publish/',
#  'https://docs.docker.com/reference/cli/docker/compose/alpha/scale/',
#  'https://docs.docker.com/reference/cli/docker/compose/alpha/viz/',
#  'https://docs.docker.com/reference/cli/docker/compose/build/',
#  'https://docs.docker.com/reference/cli/docker/compose/config/',
#  'https://docs.docker.com/reference/cli/docker/compose/cp/',
#  'https://docs.docker.com/reference/cli/docker/compose/create/',
#  'https://docs.docker.com/reference/cli/docker/compose/down/',
#  'https://docs.docker.com/reference/cli/docker/compose/events/',
#  'https://docs.docker.com/reference/cli/docker/compose/exec/',
#  'https://docs.docker.com/reference/cli/docker/compose/images/',
#  'https://docs.docker.com/reference/cli/docker/compose/kill/',
#  'https://docs.docker.com/reference/cli/docker/compose/logs/',
#  'https://docs.docker.com/reference/cli/docker/compose/ls/',
#  'https://docs.docker.com/reference/cli/docker/compose/pause/',
#  'https://docs.docker.com/reference/cli/docker/compose/port/',
#  'https://docs.docker.com/reference/cli/docker/compose/ps/',
#  'https://docs.docker.com/reference/cli/docker/compose/pull/',
#  'https://docs.docker.com/reference/cli/docker/compose/push/',
#  'https://docs.docker.com/reference/cli/docker/compose/restart/',
#  'https://docs.docker.com/reference/cli/docker/compose/rm/',
#  'https://docs.docker.com/reference/cli/docker/compose/run/',
#  'https://docs.docker.com/reference/cli/docker/compose/start/',
#  'https://docs.docker.com/reference/cli/docker/compose/stop/',
#  'https://docs.docker.com/reference/cli/docker/compose/top/',
#  'https://docs.docker.com/reference/cli/docker/compose/unpause/',
#  'https://docs.docker.com/reference/cli/docker/compose/up/',
#  'https://docs.docker.com/reference/cli/docker/compose/version/',
#  'https://docs.docker.com/reference/cli/docker/compose/wait/',
#  'https://docs.docker.com/reference/cli/docker/compose/watch/',
#  'https://docs.docker.com/reference/cli/docker/config/',
#  'https://docs.docker.com/reference/cli/docker/config/create/',
#  'https://docs.docker.com/reference/cli/docker/config/inspect/',
#  'https://docs.docker.com/reference/cli/docker/config/ls/',
#  'https://docs.docker.com/reference/cli/docker/config/rm/',
#  'https://docs.docker.com/reference/cli/docker/container/',
#  'https://docs.docker.com/reference/cli/docker/container/attach/',
#  'https://docs.docker.com/reference/cli/docker/container/commit/',
#  'https://docs.docker.com/reference/cli/docker/container/cp/',
#  'https://docs.docker.com/reference/cli/docker/container/create/',
#  'https://docs.docker.com/reference/cli/docker/container/diff/',
#  'https://docs.docker.com/build/builders/drivers/docker-container/',
#  'https://docs.docker.com/reference/cli/docker/container/exec/',
#  'https://docs.docker.com/reference/cli/docker/container/export/',
#  'https://docs.docker.com/reference/cli/docker/container/inspect/',
#  'https://docs.docker.com/reference/cli/docker/container/kill/',
#  'https://docs.docker.com/reference/cli/docker/container/logs/',
#  'https://docs.docker.com/reference/cli/docker/container/ls/',
#  'https://docs.docker.com/reference/cli/docker/container/pause/',
#  'https://docs.docker.com/reference/cli/docker/container/port/',
#  'https://docs.docker.com/reference/cli/docker/container/prune/',
#  'https://docs.docker.com/reference/cli/docker/container/rename/',
#  'https://docs.docker.com/reference/cli/docker/container/restart/',
#  'https://docs.docker.com/reference/cli/docker/container/rm/',
#  'https://docs.docker.com/reference/cli/docker/container/run/',
#  'https://docs.docker.com/reference/cli/docker/container/start/',
#  'https://docs.docker.com/reference/cli/docker/container/stats/',
#  'https://docs.docker.com/reference/cli/docker/container/stop/',
#  'https://docs.docker.com/reference/cli/docker/container/top/',
#  'https://docs.docker.com/reference/cli/docker/container/unpause/',
#  'https://docs.docker.com/reference/cli/docker/container/update/',
#  'https://docs.docker.com/reference/cli/docker/container/wait/',
#  'https://docs.docker.com/reference/cli/docker/context/',
#  'https://docs.docker.com/reference/cli/docker/context/create/',
#  'https://docs.docker.com/reference/cli/docker/context/export/',
#  'https://docs.docker.com/reference/cli/docker/context/import/',
#  'https://docs.docker.com/reference/cli/docker/context/inspect/',
#  'https://docs.docker.com/reference/cli/docker/context/ls/',
#  'https://docs.docker.com/reference/cli/docker/context/rm/',
#  'https://docs.docker.com/reference/cli/docker/context/show/',
#  'https://docs.docker.com/reference/cli/docker/context/update/',
#  'https://docs.docker.com/reference/cli/docker/context/use/',
#  'https://docs.docker.com/engine/manage-resources/contexts/',
#  'https://docs.docker.com/reference/cli/docker/debug/',
#  'https://docs.docker.com/reference/cli/docker/desktop/',
#  'https://docs.docker.com/reference/cli/docker/desktop/disable/',
#  'https://docs.docker.com/reference/cli/docker/desktop/disable/model-runner/',
#  'https://docs.docker.com/reference/cli/docker/desktop/enable/',
#  'https://docs.docker.com/reference/cli/docker/desktop/enable/model-runner/',
#  'https://docs.docker.com/reference/cli/docker/desktop/engine/',
#  'https://docs.docker.com/reference/cli/docker/desktop/engine/ls/',
#  'https://docs.docker.com/reference/cli/docker/desktop/engine/use/',
#  'https://docs.docker.com/desktop/features/dev-box/',
#  'https://docs.docker.com/reference/cli/docker/desktop/logs/',
#  'https://docs.docker.com/reference/cli/docker/desktop/module/',
#  'https://docs.docker.com/reference/cli/docker/desktop/module/ls/',
#  'https://docs.docker.com/reference/cli/docker/desktop/module/update/',
#  'https://docs.docker.com/reference/cli/docker/desktop/module/reset/',
#  'https://docs.docker.com/reference/cli/docker/desktop/restart/',
#  'https://docs.docker.com/reference/cli/docker/desktop/start/',
#  'https://docs.docker.com/reference/cli/docker/desktop/status/',
#  'https://docs.docker.com/reference/cli/docker/desktop/stop/',
#  'https://docs.docker.com/reference/cli/docker/desktop/update/',
#  'https://docs.docker.com/reference/cli/docker/desktop/version/',
#  'https://docs.docker.com/build/builders/drivers/docker/',
#  'https://docs.docker.com/reference/api/engine/',
#  'https://docs.docker.com/engine/extend/',
#  'https://docs.docker.com/reference/cli/docker/image/',
#  'https://docs.docker.com/reference/cli/docker/image/history/',
#  'https://docs.docker.com/reference/cli/docker/image/import/',
#  'https://docs.docker.com/reference/cli/docker/image/inspect/',
#  'https://docs.docker.com/reference/cli/docker/image/load/',
#  'https://docs.docker.com/reference/cli/docker/image/ls/',
#  'https://docs.docker.com/reference/cli/docker/image/prune/',
#  'https://docs.docker.com/reference/cli/docker/image/pull/',
#  'https://docs.docker.com/reference/cli/docker/image/push/',
#  'https://docs.docker.com/reference/cli/docker/image/rm/',
#  'https://docs.docker.com/reference/cli/docker/image/save/',
#  'https://docs.docker.com/reference/cli/docker/image/tag/',
#  'https://docs.docker.com/reference/cli/docker/init/',
#  'https://docs.docker.com/reference/cli/docker/inspect/',
#  'https://docs.docker.com/engine/extend/plugins_logging/',
#  'https://docs.docker.com/reference/cli/docker/login/',
#  'https://docs.docker.com/reference/cli/docker/logout/',
#  'https://docs.docker.com/reference/cli/docker/manifest/',
#  'https://docs.docker.com/reference/cli/docker/manifest/annotate/',
#  'https://docs.docker.com/reference/cli/docker/manifest/create/',
#  'https://docs.docker.com/reference/cli/docker/manifest/inspect/',
#  'https://docs.docker.com/reference/cli/docker/manifest/push/',
#  'https://docs.docker.com/reference/cli/docker/manifest/rm/',
#  'https://docs.docker.com/ai/mcp-catalog-and-toolkit/catalog/',
#  'https://docs.docker.com/reference/cli/docker/model/',
#  'https://docs.docker.com/reference/cli/docker/model/df/',
#  'https://docs.docker.com/reference/cli/docker/model/inspect/',
#  'https://docs.docker.com/reference/cli/docker/model/install-runner/',
#  'https://docs.docker.com/reference/cli/docker/model/list/',
#  'https://docs.docker.com/reference/cli/docker/model/logs/',
#  'https://docs.docker.com/reference/cli/docker/model/package/',
#  'https://docs.docker.com/reference/cli/docker/model/ps/',
#  'https://docs.docker.com/reference/cli/docker/model/pull/',
#  'https://docs.docker.com/reference/cli/docker/model/push/',
#  'https://docs.docker.com/reference/cli/docker/model/rm/',
#  'https://docs.docker.com/reference/cli/docker/model/run/',
#  'https://docs.docker.com/reference/cli/docker/model/status/',
#  'https://docs.docker.com/reference/cli/docker/model/tag/',
#  'https://docs.docker.com/reference/cli/docker/model/uninstall-runner/',
#  'https://docs.docker.com/reference/cli/docker/model/unload/',
#  'https://docs.docker.com/reference/cli/docker/model/version/',
#  'https://docs.docker.com/reference/cli/docker/network/',
#  'https://docs.docker.com/reference/cli/docker/network/connect/',
#  'https://docs.docker.com/reference/cli/docker/network/create/',
#  'https://docs.docker.com/reference/cli/docker/network/disconnect/',
#  'https://docs.docker.com/engine/extend/plugins_network/',
#  'https://docs.docker.com/reference/cli/docker/network/inspect/',
#  'https://docs.docker.com/reference/cli/docker/network/ls/',
#  'https://docs.docker.com/reference/cli/docker/network/prune/',
#  'https://docs.docker.com/reference/cli/docker/network/rm/',
#  'https://docs.docker.com/reference/cli/docker/node/',
#  'https://docs.docker.com/reference/cli/docker/node/demote/',
#  'https://docs.docker.com/reference/cli/docker/node/inspect/',
#  'https://docs.docker.com/reference/cli/docker/node/ls/',
#  'https://docs.docker.com/reference/cli/docker/node/promote/',
#  'https://docs.docker.com/reference/cli/docker/node/ps/',
#  'https://docs.docker.com/reference/cli/docker/node/rm/',
#  'https://docs.docker.com/reference/cli/docker/node/update/',
#  'https://docs.docker.com/engine/manage-resources/labels/',
#  'https://docs.docker.com/docker-hub/repos/manage/trusted-content/official-images/',
#  'https://docs.docker.com/reference/cli/docker/plugin/',
#  'https://docs.docker.com/engine/extend/plugin_api/',
#  'https://docs.docker.com/reference/cli/docker/plugin/create/',
#  'https://docs.docker.com/reference/cli/docker/plugin/disable/',
#  'https://docs.docker.com/reference/cli/docker/plugin/enable/',
#  'https://docs.docker.com/reference/cli/docker/plugin/inspect/',
#  'https://docs.docker.com/reference/cli/docker/plugin/install/',
#  'https://docs.docker.com/reference/cli/docker/plugin/ls/',
#  'https://docs.docker.com/reference/cli/docker/plugin/push/',
#  'https://docs.docker.com/reference/cli/docker/plugin/rm/',
#  'https://docs.docker.com/reference/cli/docker/plugin/set/',
#  'https://docs.docker.com/reference/cli/docker/plugin/upgrade/',
#  'https://docs.docker.com/reference/cli/docker/scout/',
#  'https://docs.docker.com/guides/docker-scout/',
#  'https://docs.docker.com/reference/cli/docker/scout/attestation/',
#  'https://docs.docker.com/reference/cli/docker/scout/attestation/add/',
#  'https://docs.docker.com/reference/cli/docker/scout/cache/',
#  'https://docs.docker.com/reference/cli/docker/scout/cache/df/',
#  'https://docs.docker.com/reference/cli/docker/scout/cache/prune/',
#  'https://docs.docker.com/reference/cli/docker/scout/compare/',
#  'https://docs.docker.com/reference/cli/docker/scout/config/',
#  'https://docs.docker.com/reference/cli/docker/scout/cves/',
#  'https://docs.docker.com/reference/cli/docker/scout/enroll/',
#  'https://docs.docker.com/reference/cli/docker/scout/environment/',
#  'https://docs.docker.com/scout/how-tos/configure-cli/',
#  'https://docs.docker.com/scout/policy/scores/',
#  'https://docs.docker.com/scout/explore/analysis/',
#  'https://docs.docker.com/reference/cli/docker/scout/integration/',
#  'https://docs.docker.com/reference/cli/docker/scout/integration/configure/',
#  'https://docs.docker.com/reference/cli/docker/scout/integration/delete/',
#  'https://docs.docker.com/reference/cli/docker/scout/integration/list/',
#  'https://docs.docker.com/scout/explore/metrics-exporter/',
#  'https://docs.docker.com/reference/cli/docker/scout/policy/',
#  'https://docs.docker.com/reference/cli/docker/scout/push/',
#  'https://docs.docker.com/reference/cli/docker/scout/quickview/',
#  'https://docs.docker.com/reference/cli/docker/scout/recommendations/',
#  'https://docs.docker.com/reference/cli/docker/scout/repo/',
#  'https://docs.docker.com/reference/cli/docker/scout/repo/disable/',
#  'https://docs.docker.com/reference/cli/docker/scout/repo/enable/',
#  'https://docs.docker.com/reference/cli/docker/scout/repo/list/',
#  'https://docs.docker.com/reference/cli/docker/scout/sbom/',
#  'https://docs.docker.com/scout/how-tos/view-create-sboms/',
#  'https://docs.docker.com/reference/cli/docker/scout/stream/',
#  'https://docs.docker.com/reference/cli/docker/scout/version/',
#  'https://docs.docker.com/reference/cli/docker/scout/watch/',
#  'https://docs.docker.com/reference/cli/docker/search/',
#  'https://docs.docker.com/reference/cli/docker/secret/',
#  'https://docs.docker.com/reference/cli/docker/secret/create/',
#  'https://docs.docker.com/reference/cli/docker/secret/inspect/',
#  'https://docs.docker.com/reference/cli/docker/secret/ls/',
#  'https://docs.docker.com/reference/cli/docker/secret/rm/',
#  'https://docs.docker.com/engine/security/non-events/',
#  'https://docs.docker.com/reference/cli/docker/service/',
#  'https://docs.docker.com/reference/cli/docker/service/create/',
#  'https://docs.docker.com/reference/cli/docker/service/inspect/',
#  'https://docs.docker.com/reference/cli/docker/service/logs/',
#  'https://docs.docker.com/reference/cli/docker/service/ls/',
#  'https://docs.docker.com/reference/cli/docker/service/ps/',
#  'https://docs.docker.com/reference/cli/docker/service/rm/',
#  'https://docs.docker.com/reference/cli/docker/service/rollback/',
#  'https://docs.docker.com/reference/cli/docker/service/scale/',
#  'https://docs.docker.com/reference/cli/docker/service/update/',
#  'https://docs.docker.com/reference/cli/docker/stack/',
#  'https://docs.docker.com/reference/cli/docker/stack/config/',
#  'https://docs.docker.com/reference/cli/docker/stack/deploy/',
#  'https://docs.docker.com/reference/cli/docker/stack/ls/',
#  'https://docs.docker.com/reference/cli/docker/stack/ps/',
#  'https://docs.docker.com/reference/cli/docker/stack/rm/',
#  'https://docs.docker.com/reference/cli/docker/stack/services/',
#  'https://docs.docker.com/reference/cli/docker/swarm/',
#  'https://docs.docker.com/reference/cli/docker/swarm/ca/',
#  'https://docs.docker.com/reference/cli/docker/swarm/init/',
#  'https://docs.docker.com/reference/cli/docker/swarm/join/',
#  'https://docs.docker.com/reference/cli/docker/swarm/join-token/',
#  'https://docs.docker.com/reference/cli/docker/swarm/leave/',
#  'https://docs.docker.com/reference/cli/docker/swarm/unlock/',
#  'https://docs.docker.com/reference/cli/docker/swarm/unlock-key/',
#  'https://docs.docker.com/reference/cli/docker/swarm/update/',
#  'https://docs.docker.com/reference/cli/docker/system/',
#  'https://docs.docker.com/reference/cli/docker/system/df/',
#  'https://docs.docker.com/reference/cli/docker/system/events/',
#  'https://docs.docker.com/reference/cli/docker/system/info/',
#  'https://docs.docker.com/reference/cli/docker/system/prune/',
#  'https://docs.docker.com/contribute/style/terminology/',
#  'https://docs.docker.com/reference/cli/docker/trust/',
#  'https://docs.docker.com/reference/cli/docker/trust/inspect/',
#  'https://docs.docker.com/reference/cli/docker/trust/key/',
#  'https://docs.docker.com/reference/cli/docker/trust/key/generate/',
#  'https://docs.docker.com/reference/cli/docker/trust/key/load/',
#  'https://docs.docker.com/reference/cli/docker/trust/revoke/',
#  'https://docs.docker.com/reference/cli/docker/trust/sign/',
#  'https://docs.docker.com/reference/cli/docker/trust/signer/',
#  'https://docs.docker.com/reference/cli/docker/trust/signer/add/',
#  'https://docs.docker.com/reference/cli/docker/trust/signer/remove/',
#  'https://docs.docker.com/docker-hub/repos/manage/trusted-content/dvp-program/',
#  'https://docs.docker.com/reference/cli/docker/version/',
#  'https://docs.docker.com/reference/cli/docker/volume/',
#  'https://docs.docker.com/reference/cli/docker/volume/create/',
#  'https://docs.docker.com/reference/cli/docker/volume/inspect/',
#  'https://docs.docker.com/reference/cli/docker/volume/ls/',
#  'https://docs.docker.com/engine/extend/plugins_volume/',
#  'https://docs.docker.com/reference/cli/docker/volume/prune/',
#  'https://docs.docker.com/reference/cli/docker/volume/rm/',
#  'https://docs.docker.com/reference/cli/docker/volume/update/',
#  'https://docs.docker.com/get-started/workshop/',
#  'https://docs.docker.com/docker-hub/repos/manage/trusted-content/dsos-program/',
#  'https://docs.docker.com/reference/cli/dockerd/',
#  'https://docs.docker.com/reference/dockerfile/',
#  'https://docs.docker.com/build/buildkit/dockerfile-release-notes/',
#  'https://docs.docker.com/security/faqs/single-sign-on/domain-faqs/',
#  'https://docs.docker.com/reference/build-checks/duplicate-stage-name/',
#  'https://docs.docker.com/get-started/resources/',
#  'https://docs.docker.com/reference/samples/elasticsearch/',
#  'https://docs.docker.com/security/faqs/single-sign-on/enforcement-faqs/',
#  'https://docs.docker.com/reference/api/engine/version/v1.24/',
#  'https://docs.docker.com/reference/api/engine/version-history/',
#  'https://docs.docker.com/engine/release-notes/17.03/',
#  'https://docs.docker.com/engine/release-notes/17.04/',
#  'https://docs.docker.com/engine/release-notes/17.05/',
#  'https://docs.docker.com/engine/release-notes/17.06/',
#  'https://docs.docker.com/engine/release-notes/17.07/',
#  'https://docs.docker.com/engine/release-notes/17.09/',
#  'https://docs.docker.com/engine/release-notes/17.10/',
#  'https://docs.docker.com/engine/release-notes/17.11/',
#  'https://docs.docker.com/engine/release-notes/17.12/',
#  'https://docs.docker.com/engine/release-notes/18.01/',
#  'https://docs.docker.com/engine/release-notes/18.02/',
#  'https://docs.docker.com/engine/release-notes/18.03/',
#  'https://docs.docker.com/engine/release-notes/18.04/',
#  'https://docs.docker.com/engine/release-notes/18.05/',
#  'https://docs.docker.com/engine/release-notes/18.06/',
#  'https://docs.docker.com/engine/release-notes/18.09/',
#  'https://docs.docker.com/engine/release-notes/19.03/',
#  'https://docs.docker.com/engine/release-notes/20.10/',
#  'https://docs.docker.com/engine/release-notes/23.0/',
#  'https://docs.docker.com/engine/release-notes/24.0/',
#  'https://docs.docker.com/engine/release-notes/25.0/',
#  'https://docs.docker.com/engine/release-notes/26.0/',
#  'https://docs.docker.com/engine/release-notes/26.1/',
#  'https://docs.docker.com/engine/release-notes/27/',
#  'https://docs.docker.com/engine/release-notes/28/',
#  'https://docs.docker.com/engine/logging/drivers/etwlogs/',
#  'https://docs.docker.com/scout/policy/ci/',
#  'https://docs.docker.com/guides/kafka/',
#  'https://docs.docker.com/reference/api/engine/sdk/examples/',
#  'https://docs.docker.com/build/ci/github-actions/export-docker/',
#  'https://docs.docker.com/reference/samples/express/',
#  'https://docs.docker.com/extensions/extensions-sdk/dev/api/backend/',
#  'https://docs.docker.com/extensions/extensions-sdk/dev/api/overview/',
#  'https://docs.docker.com/reference/api/extensions-sdk/',
#  'https://docs.docker.com/extensions/extensions-sdk/',
#  'https://docs.docker.com/guides/tensorflowjs/',
#  'https://docs.docker.com/tags/faq/',
#  'https://docs.docker.com/desktop/setup/install/enterprise-deployment/faq/',
#  'https://docs.docker.com/reference/samples/fastapi/',
#  'https://docs.docker.com/reference/samples/flask/',
#  'https://docs.docker.com/engine/logging/drivers/fluentd/',
#  'https://docs.docker.com/tags/frameworks/',
#  'https://docs.docker.com/reference/build-checks/from-as-casing/',
#  'https://docs.docker.com/reference/build-checks/from-platform-flag-const-disallowed/',
#  'https://docs.docker.com/scout/integrations/environment/cli/',
#  'https://docs.docker.com/get-started/',
#  'https://docs.docker.com/engine/swarm/swarm-tutorial/',
#  'https://docs.docker.com/reference/samples/gitea/',
#  'https://docs.docker.com/scout/integrations/source-code-management/github/',
#  'https://docs.docker.com/build/ci/github-actions/',
#  'https://docs.docker.com/scout/integrations/ci/gha/',
#  'https://docs.docker.com/guides/gha/',
#  'https://docs.docker.com/build/cache/backends/gha/',
#  'https://docs.docker.com/scout/integrations/ci/gitlab/',
#  'https://docs.docker.com/reference/glossary/',
#  'https://docs.docker.com/guides/golang/',
#  'https://docs.docker.com/reference/samples/go/',
#  'https://docs.docker.com/engine/logging/drivers/gcplogs/',
#  'https://docs.docker.com/engine/logging/drivers/gelf/',
#  'https://docs.docker.com/guides/',
#  'https://docs.docker.com',
#  'https://docs.docker.com/engine/network/drivers/host/',
#  'https://docs.docker.com/guides/traefik/',
#  'https://docs.docker.com/contribute/components/icons/',
#  'https://docs.docker.com/security/faqs/single-sign-on/idp-faqs/',
#  'https://docs.docker.com/build/exporters/image-registry/',
#  'https://docs.docker.com/build/metadata/attestations/attestation-storage/',
#  'https://docs.docker.com/scout/explore/image-details-view/',
#  'https://docs.docker.com/contribute/components/images/',
#  'https://docs.docker.com/compose/how-tos/multiple-compose-files/include/',
#  'https://docs.docker.com/build/cache/backends/inline/',
#  'https://docs.docker.com/admin/organization/insights/',
#  'https://docs.docker.com/docker-hub/repos/manage/trusted-content/insights-analytics/',
#  'https://docs.docker.com/scout/integrations/environment/',
#  'https://docs.docker.com/extensions/extensions-sdk/guides/kubernetes/',
#  'https://docs.docker.com/reference/api/extensions-sdk/BackendV0/',
#  'https://docs.docker.com/reference/api/extensions-sdk/DesktopUI/',
#  'https://docs.docker.com/reference/api/extensions-sdk/Dialog/',
#  'https://docs.docker.com/reference/api/extensions-sdk/Docker/',
#  'https://docs.docker.com/reference/api/extensions-sdk/DockerCommand/',
#  'https://docs.docker.com/reference/api/extensions-sdk/DockerDesktopClient/',
#  'https://docs.docker.com/reference/api/extensions-sdk/Exec/',
#  'https://docs.docker.com/reference/api/extensions-sdk/ExecOptions/',
#  'https://docs.docker.com/reference/api/extensions-sdk/ExecProcess/',
#  'https://docs.docker.com/reference/api/extensions-sdk/ExecResult/',
#  'https://docs.docker.com/reference/api/extensions-sdk/ExecResultV0/',
#  'https://docs.docker.com/reference/api/extensions-sdk/ExecStreamOptions/',
#  'https://docs.docker.com/reference/api/extensions-sdk/Extension/',
#  'https://docs.docker.com/reference/api/extensions-sdk/ExtensionCli/',
#  'https://docs.docker.com/reference/api/extensions-sdk/ExtensionHost/',
#  'https://docs.docker.com/reference/api/extensions-sdk/ExtensionVM/',
#  'https://docs.docker.com/reference/api/extensions-sdk/Host/',
#  'https://docs.docker.com/reference/api/extensions-sdk/HttpService/',
#  'https://docs.docker.com/reference/api/extensions-sdk/NavigationIntents/',
#  'https://docs.docker.com/reference/api/extensions-sdk/OpenDialogResult/',
#  'https://docs.docker.com/reference/api/extensions-sdk/RawExecResult/',
#  'https://docs.docker.com/reference/api/extensions-sdk/RequestConfig/',
#  'https://docs.docker.com/reference/api/extensions-sdk/RequestConfigV0/',
#  'https://docs.docker.com/reference/api/extensions-sdk/ServiceError/',
#  'https://docs.docker.com/reference/api/extensions-sdk/SpawnOptions/',
#  'https://docs.docker.com/reference/api/extensions-sdk/Toast/',
#  'https://docs.docker.com/reference/build-checks/invalid-default-arg-in-from/',
#  'https://docs.docker.com/reference/build-checks/invalid-definition-description/',
#  'https://docs.docker.com/extensions/extensions-sdk/guides/invoke-host-binaries/',
#  'https://docs.docker.com/engine/network/drivers/ipvlan/',
#  'https://docs.docker.com/engine/security/userns-remap/',
#  'https://docs.docker.com/guides/java/',
#  'https://docs.docker.com/reference/samples/java/',
#  'https://docs.docker.com/reference/samples/javascript/',
#  'https://docs.docker.com/scout/integrations/ci/jenkins/',
#  'https://docs.docker.com/engine/swarm/join-nodes/',
#  'https://docs.docker.com/engine/logging/drivers/journald/',
#  'https://docs.docker.com/engine/logging/drivers/json-file/',
#  'https://docs.docker.com/reference/build-checks/json-args-recommended/',
#  ...]

# %%
url_list.extend(kubernetes_url)
url_list.extend(js_urls)
url_list.extend(["https://developer.mozilla.org/fr/docs/Web/JavaScript", "https://scikit-learn.org/stable/user_guide.html"])

# %%
df = pl.DataFrame({
    "url": url_list
})
df
# Out:
# shape: (12_534, 1)
# ┌─────────────────────────────────┐
# │ url                             │
# │ ---                             │
# │ str                             │
# ╞═════════════════════════════════╡
# │ https://docs.docker.com/refere… │
# │ https://docs.docker.com/get-st… │
# │ https://docs.docker.com/get-st… │
# │ https://docs.docker.com/get-st… │
# │ https://docs.docker.com/get-st… │
# │ …                               │
# │ https://kubernetes.io/fr/docs/… │
# │ https://kubernetes.io/fr/       │
# │ https://kubernetes.io/fr/docs/… │
# │ https://developer.mozilla.org/… │
# │ https://scikit-learn.org/stabl… │
# └─────────────────────────────────┘

# %%
def get_language_from_url(url:str) -> str | None :
    try:
        if "python.org" in url: return "Python"
        if "nextjs.org" in url: return "NextJS"
        if "docker.com" in url: return "Docker"
        if "kubernetes" in url: return "Kubernetes"
        if "djangoproject.com" in url: return "Django"
        if "pytorch" in url: return "Pytorch"
        if"scikit-learn.org" in url: return "Scikit-Learn"
        if "mozilla" in url: return "JavaScript"
    except Exception as e:
        raise

# %%
df = df.with_columns(
    pl.col("url").map_elements(
        get_language_from_url,
        return_dtype=pl.String
    ).alias("language")
)
df
# Out:
# shape: (12_534, 2)
# ┌─────────────────────────────────┬──────────────┐
# │ url                             ┆ language     │
# │ ---                             ┆ ---          │
# │ str                             ┆ str          │
# ╞═════════════════════════════════╪══════════════╡
# │ https://docs.docker.com/refere… ┆ Docker       │
# │ https://docs.docker.com/get-st… ┆ Docker       │
# │ https://docs.docker.com/get-st… ┆ Docker       │
# │ https://docs.docker.com/get-st… ┆ Docker       │
# │ https://docs.docker.com/get-st… ┆ Docker       │
# │ …                               ┆ …            │
# │ https://kubernetes.io/fr/docs/… ┆ Kubernetes   │
# │ https://kubernetes.io/fr/       ┆ Kubernetes   │
# │ https://kubernetes.io/fr/docs/… ┆ Kubernetes   │
# │ https://developer.mozilla.org/… ┆ JavaScript   │
# │ https://scikit-learn.org/stabl… ┆ Scikit-Learn │
# └─────────────────────────────────┴──────────────┘

# %%
df.group_by("language").count()
# Out:
# /var/folders/_h/w2qxb92x4fv_wv7r_mqx4kg40000gn/T/ipykernel_67262/3050384244.py:1: DeprecationWarning: `GroupBy.count` was renamed; use `GroupBy.len` instead
#   df.group_by("language").count()
# shape: (6, 2)
# ┌──────────────┬───────┐
# │ language     ┆ count │
# │ ---          ┆ ---   │
# │ str          ┆ u32   │
# ╞══════════════╪═══════╡
# │ JavaScript   ┆ 1     │
# │ NextJS       ┆ 568   │
# │ Scikit-Learn ┆ 1     │
# │ Kubernetes   ┆ 1817  │
# │ Django       ┆ 8938  │
# │ Docker       ┆ 1209  │
# └──────────────┴───────┘

# %%
df.filter(
    pl.int_range(pl.len()).shuffle().over("language") < 10
)
# Out:
# shape: (42, 2)
# ┌─────────────────────────────────┬──────────────┐
# │ url                             ┆ language     │
# │ ---                             ┆ ---          │
# │ str                             ┆ str          │
# ╞═════════════════════════════════╪══════════════╡
# │ https://docs.docker.com/get-st… ┆ Docker       │
# │ https://docs.docker.com/guides… ┆ Docker       │
# │ https://docs.docker.com/refere… ┆ Docker       │
# │ https://docs.docker.com/refere… ┆ Docker       │
# │ https://docs.docker.com/docker… ┆ Docker       │
# │ …                               ┆ …            │
# │ https://nextjs.org/learn/pages… ┆ NextJS       │
# │ https://nextjs.org/learn/pages… ┆ NextJS       │
# │ https://nextjs.org/learn/seo/i… ┆ NextJS       │
# │ https://developer.mozilla.org/… ┆ JavaScript   │
# │ https://scikit-learn.org/stabl… ┆ Scikit-Learn │
# └─────────────────────────────────┴──────────────┘

# %%
def get_crawled_urls(url:str) :
    to_visit, known_links = focused_crawler(url, max_seen_urls = 2, max_known_urls=150)
    return known_links

# %%
df.with_columns(
    pl.col("url").map_elements(
        get_crawled_urls,
        return_dtype=list
    ).alias("crawled_urls")
)
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df.with_columns(
#       2     pl.col("url").map_elements(
#       3         get_crawled_urls,
#       4         return_dtype=list
#       5     ).alias("crawled_urls")
#       6 )
#       7 df
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/polars/dataframe/frame.py:9938, in DataFrame.with_columns(self, *exprs, **named_exprs)
#    9792 """
#    9793 Add columns to this DataFrame.
#    9794
#    (...)   9931 └─────┴──────┴─────────────┘
#    9932 """
#    9933 from polars.lazyframe.opt_flags import QueryOptFlags
#    9935 return (
#    9936     self.lazy()
#    9937     .with_columns(*exprs, **named_exprs)
# -> 9938     .collect(optimizations=QueryOptFlags._eager())
#    9939 )
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/polars/lazyframe/opt_flags.py:331, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     328         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     330 kwargs["optimizations"] = optflags
# --> 331 return function(*args, **kwargs)
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/polars/lazyframe/frame.py:2300, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2298 # Only for testing purposes
#    2299 callback = _kwargs.get("post_opt_callback", callback)
# -> 2300 return wrap_df(ldf.collect(engine, callback))
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/polars/expr/expr.py:4339, in Expr._map_batches_wrapper.__call__(self, *args, **kwargs)
#    4338 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# -> 4339     result = self.function(*args, **kwargs)
#    4340     if _check_for_numpy(result) and isinstance(result, np.ndarray):
#    4341         result = pl.Series(result, dtype=self.return_dtype)
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/polars/expr/expr.py:4752, in Expr.map_elements.<locals>.wrap_f(x)
#    4750 with warnings.catch_warnings():
#    4751     warnings.simplefilter("ignore", PolarsInefficientMapWarning)
# -> 4752     return x.map_elements(
#    4753         function, return_dtype=return_dtype, skip_nulls=skip_nulls
#    4754     )
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/polars/series/series.py:5607, in Series.map_elements(self, function, return_dtype, skip_nulls)
#    5603     pl_return_dtype = parse_into_dtype(return_dtype)
#    5605 warn_on_inefficient_map(function, columns=[self.name], map_target="series")
#    5606 return self._from_pyseries(
# -> 5607     self._s.map_elements(
#    5608         function, return_dtype=pl_return_dtype, skip_nulls=skip_nulls
#    5609     )
#    5610 )
#
# Cell In[73], line 2, in get_crawled_urls(url)
#       1 def get_crawled_urls(url:str) :
# ----> 2     to_visit, known_links = focused_crawler(url, max_seen_urls = 2, max_known_urls=150)
#       3     bis_visit, bis_known = focused_crawler(url, max_seen_urls=2, max_known_urls=150, todo=to_visit, known_links=known_links)
#       4     return bis_known
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/trafilatura/spider.py:335, in focused_crawler(homepage, max_seen_urls, max_known_urls, todo, known_links, lang, config, rules, prune_xpath)
#     306 def focused_crawler(
#     307     homepage: str,
#     308     max_seen_urls: int = MAX_SEEN_URLS,
#    (...)    315     prune_xpath: Optional[str] = None,
#     316 ) -> Tuple[List[str], List[str]]:
#     317     """Basic crawler targeting pages of interest within a website.
#     318
#     319     Args:
#    (...)    333
#     334     """
# --> 335     params = init_crawl(homepage, lang, rules, todo, known_links, prune_xpath)
#     337     sleep_time = URL_STORE.get_crawl_delay(
#     338         params.base, default=config.getfloat("DEFAULT", "SLEEP_TIME")
#     339     )
#     341     # visit pages until a limit is reached
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/trafilatura/spider.py:268, in init_crawl(start, lang, rules, todo, known, prune_xpath)
#     266 if not todo:
#     267     URL_STORE.add_urls(urls=[params.start], visited=False)
# --> 268     params = crawl_page(params, initial=True)
#     269 else:
#     270     params.update_metadata(URL_STORE)
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/trafilatura/spider.py:291, in crawl_page(params, initial)
#     287 params.i += 1
#     289 if initial:
#     290     # probe and process homepage
# --> 291     htmlstring, homepage, new_base_url = probe_alternative_homepage(url)
#     292     if htmlstring and homepage and new_base_url:
#     293         # register potentially new homepage
#     294         URL_STORE.add_urls([homepage])
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/trafilatura/spider.py:138, in probe_alternative_homepage(homepage)
#     134 def probe_alternative_homepage(
#     135     homepage: str,
#     136 ) -> Tuple[Optional[str], Optional[str], Optional[str]]:
#     137     "Check if the homepage is redirected and return appropriate values."
# --> 138     response = fetch_response(homepage, decode=False)
#     139     if not response or not response.data:
#     140         return None, None, None
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/trafilatura/downloads.py:314, in fetch_response(url, decode, no_ssl, with_headers, config)
#     312 dl_function = _send_urllib_request if not HAS_PYCURL else _send_pycurl_request
#     313 LOGGER.debug("sending request: %s", url)
# --> 314 response = dl_function(url, no_ssl, with_headers, config)  # Response
#     315 if not response:  # None or ""
#     316     LOGGER.debug("request failed: %s", url)
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/trafilatura/downloads.py:212, in _send_urllib_request(url, no_ssl, with_headers, config)
#     209 pool_manager = _initiate_pool(config, no_ssl=no_ssl)
#     211 # execute request, stop downloading as soon as MAX_FILE_SIZE is reached
# --> 212 response = pool_manager.request(
#     213     "GET",
#     214     url,
#     215     headers=_determine_headers(config),
#     216     retries=_get_retry_strategy(config),
#     217     preload_content=False,
#     218 )
#     219 data = bytearray()
#     220 for chunk in response.stream(2**17):
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/urllib3/_request_methods.py:135, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     132     urlopen_kw["body"] = body
#     134 if method in self._encode_url_methods:
# --> 135     return self.request_encode_url(
#     136         method,
#     137         url,
#     138         fields=fields,  # type: ignore[arg-type]
#     139         headers=headers,
#     140         **urlopen_kw,
#     141     )
#     142 else:
#     143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/urllib3/_request_methods.py:182, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     179 if fields:
#     180     url += "?" + urlencode(fields)
# --> 182 return self.urlopen(method, url, **extra_kw)
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:942, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     940     retries.sleep(response)
#     941     log.debug("Retry: %s", url)
# --> 942     return self.urlopen(
#     943         method,
#     944         url,
#     945         body,
#     946         headers,
#     947         retries=retries,
#     948         redirect=redirect,
#     949         assert_same_host=assert_same_host,
#     950         timeout=timeout,
#     951         pool_timeout=pool_timeout,
#     952         release_conn=release_conn,
#     953         chunked=chunked,
#     954         body_pos=body_pos,
#     955         preload_content=preload_content,
#     956         decode_content=decode_content,
#     957         **response_kw,
#     958     )
#     960 return response
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:940, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     937     return response
#     939 response.drain_conn()
# --> 940 retries.sleep(response)
#     941 log.debug("Retry: %s", url)
#     942 return self.urlopen(
#     943     method,
#     944     url,
#    (...)    957     **response_kw,
#     958 )
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:363, in Retry.sleep(self, response)
#     360     if slept:
#     361         return
# --> 363 self._sleep_backoff()
#
# File ~/Documents/devsearch-engine/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:347, in Retry._sleep_backoff(self)
#     345 if backoff <= 0:
#     346     return
# --> 347 time.sleep(backoff)
#
# KeyboardInterrupt:

# %%
from trafilatura import fetch_url, extract

# %%
downloaded = fetch_url("https://docs.python.org/3.13/")
extract(downloaded, output_format="json", with_metadata=True)
# Out:
# '{"title": "Python 3.13 documentation", "author": null, "hostname": "python.org", "date": "2013-04-03", "fingerprint": "10333eedeccee290", "id": null, "license": null, "comments": "", "raw_text": "Python 3.13.4 documentation Welcome! This is the official documentation for Python 3.13.4. Documentation sections: What\'s new in Python 3.13? Or all \\"What\'s new\\" documents since Python 2.0 Tutorial Start here: a tour of Python\'s syntax and features Library reference Standard library and builtins Language reference Syntax and language elements Python setup and usage How to install, configure, and use Python Python HOWTOs In-depth topic manuals Installing Python modules Third-party modules and PyPI.org Distributing Python modules Publishing modules for use by other people Extending and embedding For C/C++ programmers Python\'s C API C API reference FAQs Frequently asked questions (with answers!) Deprecations Deprecated functionality Indices, glossary, and search: Global module index All modules and libraries General index All functions, classes, and terms Glossary Terms explained Search page Search this documentation Complete table of contents Lists all sections and subsections Project information:", "text": "Python 3.13.4 documentation\\nWelcome! This is the official documentation for Python 3.13.4.\\nDocumentation sections:\\n|\\nWhat\'s new in Python 3.13?\\nOr all \\"What\'s new\\" documents since Python 2.0\\nTutorial\\nStart here: a tour of Python\'s syntax and features\\nLibrary reference\\nStandard library and builtins\\nLanguage reference\\nSyntax and language elements\\nPython setup and usage\\nHow to install, configure, and use Python\\nPython HOWTOs\\nIn-depth topic manuals\\n|\\nInstalling Python modules\\nThird-party modules and PyPI.org\\nDistributing Python modules\\nPublishing modules for use by other people\\nExtending and embedding\\nFor C/C++ programmers\\nPython\'s C API\\nC API reference\\nFAQs\\nFrequently asked questions (with answers!)\\nDeprecations\\nDeprecated functionality\\n|\\nIndices, glossary, and search:\\n|\\nGlobal module index\\nAll modules and libraries\\nGeneral index\\nAll functions, classes, and terms\\nGlossary\\nTerms explained\\n|\\nSearch page\\nSearch this documentation\\nComplete table of contents\\nLists all sections and subsections\\n|\\nProject information:", "language": null, "image": "https://docs.python.org/3/_static/og-image.png", "pagetype": "website", "filedate": "2025-06-05", "source": "https://docs.python.org/3/", "source-hostname": "Python documentation", "excerpt": "The official Python documentation.", "categories": "", "tags": ""}'

# %%
ORDER = ['id',"title", "content", "file_type", "path", "created_at", "modified_at", "github_stars", "view_count","language", "tags", "source"]

# %%
df_SO = pl.read_csv("./SO_sample.csv", separator=";", try_parse_dates=True)
df_SO.head(10)
# Out:
# shape: (10, 8)
# ┌─────┬──────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────────┬────────────┐
# │     ┆ id       ┆ title       ┆ body        ┆ comment_cou ┆ creation_da ┆ last_activ ┆ tags       │
# │ --- ┆ ---      ┆ ---         ┆ ---         ┆ nt          ┆ te          ┆ ity_date   ┆ ---        │
# │ i64 ┆ i64      ┆ str         ┆ str         ┆ ---         ┆ ---         ┆ ---        ┆ str        │
# │     ┆          ┆             ┆             ┆ i64         ┆ datetime[μs ┆ datetime[μ ┆            │
# │     ┆          ┆             ┆             ┆             ┆ , UTC]      ┆ s, UTC]    ┆            │
# ╞═════╪══════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════╪════════════╡
# │ 0   ┆ 42067644 ┆ Data        ┆ <p>Consider ┆ 11          ┆ 2017-02-06  ┆ 2017-02-06 ┆ android|se │
# │     ┆          ┆ sharing     ┆ a data      ┆             ┆ 12:18:31.57 ┆ 15:08:30.2 ┆ rvice|usb| │
# │     ┆          ┆ (one way    ┆ being       ┆             ┆ 0 UTC       ┆ 53 UTC     ┆ background │
# │     ┆          ┆ communic…   ┆ gener…      ┆             ┆             ┆            ┆ …          │
# │ 1   ┆ 41695757 ┆ Error       ┆ <p>When i   ┆ 11          ┆ 2017-01-17  ┆ 2017-01-17 ┆ git|visual │
# │     ┆          ┆ encountered ┆ try to push ┆             ┆ 11:18:08.23 ┆ 12:45:51.6 ┆ -studio|vi │
# │     ┆          ┆ while       ┆ any git …   ┆             ┆ 3 UTC       ┆ 70 UTC     ┆ sual-studi │
# │     ┆          ┆ pushin…     ┆             ┆             ┆             ┆            ┆ …          │
# │ 2   ┆ 41901824 ┆ Seems like  ┆ <p>Below is ┆ 11          ┆ 2017-01-27  ┆ 2017-02-25 ┆ sql|sql-se │
# │     ┆          ┆ a bug in    ┆ the script  ┆             ┆ 19:42:52.37 ┆ 16:40:22.6 ┆ rver|azure │
# │     ┆          ┆ Azure SQL … ┆ I am ru…    ┆             ┆ 3 UTC       ┆ 80 UTC     ┆ |azure-sql │
# │     ┆          ┆             ┆             ┆             ┆             ┆            ┆ …          │
# │ 3   ┆ 42122582 ┆ Android     ┆ <p>I'm      ┆ 11          ┆ 2017-02-08  ┆ 2019-12-18 ┆ android|de │
# │     ┆          ┆ deep link   ┆ trying to   ┆             ┆ 20:03:58.07 ┆ 04:20:18.5 ┆ ep-linking │
# │     ┆          ┆ gives web   ┆ share a     ┆             ┆ 0 UTC       ┆ 70 UTC     ┆            │
# │     ┆          ┆ pa…         ┆ link …      ┆             ┆             ┆            ┆            │
# │ 4   ┆ 42082800 ┆ segfault    ┆ <p>So my    ┆ 11          ┆ 2017-02-07  ┆ 2017-02-07 ┆ c++        │
# │     ┆          ┆ when        ┆ unordered   ┆             ┆ 06:02:19.58 ┆ 06:18:36.6 ┆            │
# │     ┆          ┆ indexing [] ┆ map is a    ┆             ┆ 3 UTC       ┆ 00 UTC     ┆            │
# │     ┆          ┆ into…       ┆ ma…         ┆             ┆             ┆            ┆            │
# │ 5   ┆ 41808100 ┆ Read file   ┆ <p>This is  ┆ 11          ┆ 2017-01-23  ┆ 2017-01-23 ┆ c|file     │
# │     ┆          ┆ as hex in C ┆ my current  ┆             ┆ 13:59:24.08 ┆ 16:05:32.2 ┆            │
# │     ┆          ┆             ┆ code:</p…   ┆             ┆ 0 UTC       ┆ 63 UTC     ┆            │
# │ 6   ┆ 41993460 ┆ 500         ┆ <p>Kindly   ┆ 11          ┆ 2017-02-02  ┆ 2017-02-02 ┆ php|apache │
# │     ┆          ┆ Internal    ┆ help me,    ┆             ┆ 02:54:12.75 ┆ 02:54:12.7 ┆ |laravel|l │
# │     ┆          ┆ Server      ┆ </p>        ┆             ┆ 7 UTC       ┆ 57 UTC     ┆ aravel-5.3 │
# │     ┆          ┆ Error. mal… ┆             ┆             ┆             ┆            ┆            │
# │     ┆          ┆             ┆ <p>M…       ┆             ┆             ┆            ┆            │
# │ 7   ┆ 41973876 ┆ Strange     ┆ <p>I am     ┆ 11          ┆ 2017-02-01  ┆ 2017-02-02 ┆ fortran|gf │
# │     ┆          ┆ behavior    ┆ trying to   ┆             ┆ 07:09:25.65 ┆ 09:33:52.1 ┆ ortran     │
# │     ┆          ┆ while       ┆ use         ┆             ┆ 0 UTC       ┆ 40 UTC     ┆            │
# │     ┆          ┆ calling…    ┆ REFPROPs…   ┆             ┆             ┆            ┆            │
# │ 8   ┆ 41816885 ┆ Copying the ┆ <p>I'm      ┆ 11          ┆ 2017-01-23  ┆ 2017-01-28 ┆ c          │
# │     ┆          ┆ lines from  ┆ trying to   ┆             ┆ 22:34:28.94 ┆ 13:55:57.1 ┆            │
# │     ┆          ┆ a file …    ┆ copy the    ┆             ┆ 7 UTC       ┆ 07 UTC     ┆            │
# │     ┆          ┆             ┆ file…       ┆             ┆             ┆            ┆            │
# │ 9   ┆ 41794627 ┆ Can't       ┆ <p>When I   ┆ 11          ┆ 2017-01-22  ┆ 2017-03-07 ┆ java|googl │
# │     ┆          ┆ create cron ┆ deploy my   ┆             ┆ 18:28:39.23 ┆ 00:20:34.9 ┆ e-app-engi │
# │     ┆          ┆ job in      ┆ applicatio… ┆             ┆ 3 UTC       ┆ 63 UTC     ┆ ne|cron    │
# │     ┆          ┆ Googl…      ┆             ┆             ┆             ┆            ┆            │
# └─────┴──────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────────┴────────────┘

# %%
df_SO = df_SO.with_columns(
    pl.col("tags").str.split(by="|").alias("tag_list")
)
df_SO
# Out:
# shape: (5_000, 9)
# ┌──────┬──────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │      ┆ id       ┆ title      ┆ body       ┆ … ┆ creation_d ┆ last_activ ┆ tags       ┆ tag_list  │
# │ ---  ┆ ---      ┆ ---        ┆ ---        ┆   ┆ ate        ┆ ity_date   ┆ ---        ┆ ---       │
# │ i64  ┆ i64      ┆ str        ┆ str        ┆   ┆ ---        ┆ ---        ┆ str        ┆ list[str] │
# │      ┆          ┆            ┆            ┆   ┆ datetime[μ ┆ datetime[μ ┆            ┆           │
# │      ┆          ┆            ┆            ┆   ┆ s, UTC]    ┆ s, UTC]    ┆            ┆           │
# ╞══════╪══════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 0    ┆ 42067644 ┆ Data       ┆ <p>Conside ┆ … ┆ 2017-02-06 ┆ 2017-02-06 ┆ android|se ┆ ["android │
# │      ┆          ┆ sharing    ┆ r a data   ┆   ┆ 12:18:31.5 ┆ 15:08:30.2 ┆ rvice|usb| ┆ ", "servi │
# │      ┆          ┆ (one way   ┆ being      ┆   ┆ 70 UTC     ┆ 53 UTC     ┆ background ┆ ce", …    │
# │      ┆          ┆ communic…  ┆ gener…     ┆   ┆            ┆            ┆ …          ┆ "back…    │
# │ 1    ┆ 41695757 ┆ Error enco ┆ <p>When i  ┆ … ┆ 2017-01-17 ┆ 2017-01-17 ┆ git|visual ┆ ["git",   │
# │      ┆          ┆ untered    ┆ try to     ┆   ┆ 11:18:08.2 ┆ 12:45:51.6 ┆ -studio|vi ┆ "visual-s │
# │      ┆          ┆ while      ┆ push any   ┆   ┆ 33 UTC     ┆ 70 UTC     ┆ sual-studi ┆ tudio", … │
# │      ┆          ┆ pushin…    ┆ git …      ┆   ┆            ┆            ┆ …          ┆ "tf…      │
# │ 2    ┆ 41901824 ┆ Seems like ┆ <p>Below   ┆ … ┆ 2017-01-27 ┆ 2017-02-25 ┆ sql|sql-se ┆ ["sql",   │
# │      ┆          ┆ a bug in   ┆ is the     ┆   ┆ 19:42:52.3 ┆ 16:40:22.6 ┆ rver|azure ┆ "sql-serv │
# │      ┆          ┆ Azure SQL  ┆ script I   ┆   ┆ 73 UTC     ┆ 80 UTC     ┆ |azure-sql ┆ er", …    │
# │      ┆          ┆ …          ┆ am ru…     ┆   ┆            ┆            ┆ …          ┆ "data-…   │
# │ 3    ┆ 42122582 ┆ Android    ┆ <p>I'm     ┆ … ┆ 2017-02-08 ┆ 2019-12-18 ┆ android|de ┆ ["android │
# │      ┆          ┆ deep link  ┆ trying to  ┆   ┆ 20:03:58.0 ┆ 04:20:18.5 ┆ ep-linking ┆ ", "deep- │
# │      ┆          ┆ gives web  ┆ share a    ┆   ┆ 70 UTC     ┆ 70 UTC     ┆            ┆ linking"] │
# │      ┆          ┆ pa…        ┆ link …     ┆   ┆            ┆            ┆            ┆           │
# │ 4    ┆ 42082800 ┆ segfault   ┆ <p>So my   ┆ … ┆ 2017-02-07 ┆ 2017-02-07 ┆ c++        ┆ ["c++"]   │
# │      ┆          ┆ when       ┆ unordered  ┆   ┆ 06:02:19.5 ┆ 06:18:36.6 ┆            ┆           │
# │      ┆          ┆ indexing   ┆ map is a   ┆   ┆ 83 UTC     ┆ 00 UTC     ┆            ┆           │
# │      ┆          ┆ [] into…   ┆ ma…        ┆   ┆            ┆            ┆            ┆           │
# │ …    ┆ …        ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …          ┆ …         │
# │ 4995 ┆ 39697065 ┆ How to     ┆ <p>In one  ┆ … ┆ 2016-09-26 ┆ 2016-09-26 ┆ jquery|asp ┆ ["jquery" │
# │      ┆          ┆ display    ┆ of my mvc4 ┆   ┆ 07:33:20.3 ┆ 09:30:45.7 ┆ .net-mvc|a ┆ , "asp.ne │
# │      ┆          ┆ downloaded ┆ applicati… ┆   ┆ 63 UTC     ┆ 70 UTC     ┆ sp.net-mvc ┆ t-mvc",   │
# │      ┆          ┆ file…      ┆            ┆   ┆            ┆            ┆ …          ┆ "asp…     │
# │ 4996 ┆ 39769970 ┆ Inserting  ┆ <p>I have  ┆ … ┆ 2016-09-29 ┆ 2016-09-29 ┆ android|im ┆ ["android │
# │      ┆          ┆ logo image ┆ been       ┆   ┆ 12:10:48.9 ┆ 13:13:43.7 ┆ ageview    ┆ ", "image │
# │      ┆          ┆ into appl… ┆ trying and ┆   ┆ 87 UTC     ┆ 00 UTC     ┆            ┆ view"]    │
# │      ┆          ┆            ┆ tryi…      ┆   ┆            ┆            ┆            ┆           │
# │ 4997 ┆ 39708082 ┆ What       ┆ <p>We use  ┆ … ┆ 2016-09-26 ┆ 2018-11-11 ┆ git|git-co ┆ ["git",   │
# │      ┆          ┆ problem or ┆ GitHub and ┆   ┆ 16:40:35.8 ┆ 12:02:59.4 ┆ mmit|sign  ┆ "git-comm │
# │      ┆          ┆ threat     ┆ we have a… ┆   ┆ 73 UTC     ┆ 20 UTC     ┆            ┆ it",      │
# │      ┆          ┆ does co…   ┆            ┆   ┆            ┆            ┆            ┆ "sign"]   │
# │ 4998 ┆ 39455252 ┆ Variable-L ┆ <p>I want  ┆ … ┆ 2016-09-12 ┆ 2016-09-12 ┆ c|arrays|v ┆ ["c",     │
# │      ┆          ┆ ength      ┆ to create  ┆   ┆ 16:59:04.3 ┆ 17:54:25.4 ┆ ariable-le ┆ "arrays", │
# │      ┆          ┆ Arrays in  ┆ an         ┆   ┆ 00 UTC     ┆ 17 UTC     ┆ ngth-array ┆ "variable │
# │      ┆          ┆ c pr…      ┆ variabl…   ┆   ┆            ┆            ┆            ┆ -leng…    │
# │ 4999 ┆ 39716384 ┆ How to use ┆ <p>I am    ┆ … ┆ 2016-09-27 ┆ 2019-03-24 ┆ android|de ┆ ["android │
# │      ┆          ┆ MagTek     ┆ using      ┆   ┆ 05:08:23.3 ┆ 11:18:57.5 ┆ vice|credi ┆ ",        │
# │      ┆          ┆ card       ┆ magtek     ┆   ┆ 50 UTC     ┆ 10 UTC     ┆ t-card|rea ┆ "device", │
# │      ┆          ┆ reader …   ┆ card read… ┆   ┆            ┆            ┆ …          ┆ … "reade… │
# └──────┴──────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴───────────┘

# %%
df_SO = df_SO.drop(["comment_count", "tags", '']).rename({
    "creation_date": "created_at",
    "last_activity_date": "modified_at",
    "tag_list": "tags",
    "body" : "content"
}
).with_columns(
    path = pl.lit(""),
    file_type = pl.lit("blog"),
    language = pl.lit("en"),
    github_stars = pl.lit(0),
    view_count = pl.lit(0),
    source = pl.lit("Stack Overflow"),
)
df_SO.head(10)
# Out:
# shape: (10, 12)
# ┌──────────┬────────────┬───────────┬───────────┬───┬──────────┬───────────┬───────────┬───────────┐
# │ id       ┆ title      ┆ content   ┆ created_a ┆ … ┆ language ┆ github_st ┆ view_coun ┆ source    │
# │ ---      ┆ ---        ┆ ---       ┆ t         ┆   ┆ ---      ┆ ars       ┆ t         ┆ ---       │
# │ i64      ┆ str        ┆ str       ┆ ---       ┆   ┆ str      ┆ ---       ┆ ---       ┆ str       │
# │          ┆            ┆           ┆ datetime[ ┆   ┆          ┆ i32       ┆ i32       ┆           │
# │          ┆            ┆           ┆ μs, UTC]  ┆   ┆          ┆           ┆           ┆           │
# ╞══════════╪════════════╪═══════════╪═══════════╪═══╪══════════╪═══════════╪═══════════╪═══════════╡
# │ 42067644 ┆ Data       ┆ <p>Consid ┆ 2017-02-0 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ sharing    ┆ er a data ┆ 6 12:18:3 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ (one way   ┆ being     ┆ 1.570 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆ communic…  ┆ gener…    ┆           ┆   ┆          ┆           ┆           ┆           │
# │ 41695757 ┆ Error enco ┆ <p>When i ┆ 2017-01-1 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ untered    ┆ try to    ┆ 7 11:18:0 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ while      ┆ push any  ┆ 8.233 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆ pushin…    ┆ git …     ┆           ┆   ┆          ┆           ┆           ┆           │
# │ 41901824 ┆ Seems like ┆ <p>Below  ┆ 2017-01-2 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ a bug in   ┆ is the    ┆ 7 19:42:5 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ Azure SQL  ┆ script I  ┆ 2.373 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆ …          ┆ am ru…    ┆           ┆   ┆          ┆           ┆           ┆           │
# │ 42122582 ┆ Android    ┆ <p>I'm    ┆ 2017-02-0 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ deep link  ┆ trying to ┆ 8 20:03:5 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ gives web  ┆ share a   ┆ 8.070 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆ pa…        ┆ link …    ┆           ┆   ┆          ┆           ┆           ┆           │
# │ 42082800 ┆ segfault   ┆ <p>So my  ┆ 2017-02-0 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ when       ┆ unordered ┆ 7 06:02:1 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ indexing   ┆ map is a  ┆ 9.583 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆ [] into…   ┆ ma…       ┆           ┆   ┆          ┆           ┆           ┆           │
# │ 41808100 ┆ Read file  ┆ <p>This   ┆ 2017-01-2 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ as hex in  ┆ is my     ┆ 3 13:59:2 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ C          ┆ current   ┆ 4.080 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆            ┆ code:</p… ┆           ┆   ┆          ┆           ┆           ┆           │
# │ 41993460 ┆ 500        ┆ <p>Kindly ┆ 2017-02-0 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ Internal   ┆ help me,  ┆ 2 02:54:1 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ Server     ┆ </p>      ┆ 2.757 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆ Error.     ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │          ┆ mal…       ┆ <p>M…     ┆           ┆   ┆          ┆           ┆           ┆           │
# │ 41973876 ┆ Strange    ┆ <p>I am   ┆ 2017-02-0 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ behavior   ┆ trying to ┆ 1 07:09:2 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ while      ┆ use       ┆ 5.650 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆ calling…   ┆ REFPROPs… ┆           ┆   ┆          ┆           ┆           ┆           │
# │ 41816885 ┆ Copying    ┆ <p>I'm    ┆ 2017-01-2 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ the lines  ┆ trying to ┆ 3 22:34:2 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ from a     ┆ copy the  ┆ 8.947 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆ file …     ┆ file…     ┆           ┆   ┆          ┆           ┆           ┆           │
# │ 41794627 ┆ Can't      ┆ <p>When I ┆ 2017-01-2 ┆ … ┆ en       ┆ 0         ┆ 0         ┆ Stack     │
# │          ┆ create     ┆ deploy my ┆ 2 18:28:3 ┆   ┆          ┆           ┆           ┆ Overflow  │
# │          ┆ cron job   ┆ applicati ┆ 9.233 UTC ┆   ┆          ┆           ┆           ┆           │
# │          ┆ in Googl…  ┆ o…        ┆           ┆   ┆          ┆           ┆           ┆           │
# └──────────┴────────────┴───────────┴───────────┴───┴──────────┴───────────┴───────────┴───────────┘

# %%
from bs4 import BeautifulSoup
import re

# %%
def personal_extractor(text: str):

    if not isinstance(text, str):
        return ""
   
    soup = BeautifulSoup(text, "html.parser")
   
    for pre_tag in soup.find_all("pre"):
        pre_tag.decompose()
    
    for code_tag in soup.find_all("code"):
        code_tag.decompose()
    
    text_content = soup.get_text(separator=" ", strip=True)

    text_content = re.sub(r'\s+', " ", text_content).strip()
    return text_content

# %%
df_SO = df_SO.with_columns([
    pl.col("content").map_elements(
        personal_extractor,
        return_dtype=str
    ).alias("raw HTML"),
    pl.col("id").map_elements(
        str,
        return_dtype=str
    )]
).drop(["content"]).rename({"raw HTML": "content"})
df_SO.head(10)
# Out:
# /var/folders/_h/w2qxb92x4fv_wv7r_mqx4kg40000gn/T/ipykernel_67262/2106179759.py:6: PolarsInefficientMapWarning:
# Expr.map_elements is significantly slower than the native expressions API.
# Only use if you absolutely CANNOT implement your logic otherwise.
# Replace this expression...
#   - pl.col("id").map_elements(str)
# with this one instead:
#   + pl.col("id").cast(pl.String)
#
#   pl.col("id").map_elements(
# /var/folders/_h/w2qxb92x4fv_wv7r_mqx4kg40000gn/T/ipykernel_67262/1605827620.py:6: MarkupResemblesLocatorWarning: The input passed in on this line looks more like a URL than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the web page found at a certain URL, then something has gone wrong. You should use an Python package like 'requests' to fetch the content behind the URL. Once you have the content as a string, you can feed that string into Beautiful Soup.
#
# However, if you want to parse some data that happens to look like a URL, then nothing has gone wrong: you are using Beautiful Soup correctly, and this warning is spurious and can be filtered. To make this warning go away, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import MarkupResemblesLocatorWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
#
#   soup = BeautifulSoup(text, "html.parser")
# shape: (10, 12)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id       ┆ title     ┆ created_a ┆ modified_ ┆ … ┆ github_st ┆ view_coun ┆ source    ┆ content   │
# │ ---      ┆ ---       ┆ t         ┆ at        ┆   ┆ ars       ┆ t         ┆ ---       ┆ ---       │
# │ str      ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ str       ┆ str       │
# │          ┆           ┆ datetime[ ┆ datetime[ ┆   ┆ i32       ┆ i32       ┆           ┆           │
# │          ┆           ┆ μs, UTC]  ┆ μs, UTC]  ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 42067644 ┆ Data      ┆ 2017-02-0 ┆ 2017-02-0 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ Consider  │
# │          ┆ sharing   ┆ 6 12:18:3 ┆ 6 15:08:3 ┆   ┆           ┆           ┆ Overflow  ┆ a data    │
# │          ┆ (one way  ┆ 1.570 UTC ┆ 0.253 UTC ┆   ┆           ┆           ┆           ┆ being     │
# │          ┆ communic… ┆           ┆           ┆   ┆           ┆           ┆           ┆ generate… │
# │ 41695757 ┆ Error enc ┆ 2017-01-1 ┆ 2017-01-1 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ When i    │
# │          ┆ ountered  ┆ 7 11:18:0 ┆ 7 12:45:5 ┆   ┆           ┆           ┆ Overflow  ┆ try to    │
# │          ┆ while     ┆ 8.233 UTC ┆ 1.670 UTC ┆   ┆           ┆           ┆           ┆ push any  │
# │          ┆ pushin…   ┆           ┆           ┆   ┆           ┆           ┆           ┆ git com…  │
# │ 41901824 ┆ Seems     ┆ 2017-01-2 ┆ 2017-02-2 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ Below is  │
# │          ┆ like a    ┆ 7 19:42:5 ┆ 5 16:40:2 ┆   ┆           ┆           ┆ Overflow  ┆ the       │
# │          ┆ bug in    ┆ 2.373 UTC ┆ 2.680 UTC ┆   ┆           ┆           ┆           ┆ script I  │
# │          ┆ Azure SQL ┆           ┆           ┆   ┆           ┆           ┆           ┆ am runni… │
# │          ┆ …         ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 42122582 ┆ Android   ┆ 2017-02-0 ┆ 2019-12-1 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ I'm       │
# │          ┆ deep link ┆ 8 20:03:5 ┆ 8 04:20:1 ┆   ┆           ┆           ┆ Overflow  ┆ trying to │
# │          ┆ gives web ┆ 8.070 UTC ┆ 8.570 UTC ┆   ┆           ┆           ┆           ┆ share a   │
# │          ┆ pa…       ┆           ┆           ┆   ┆           ┆           ┆           ┆ link for… │
# │ 42082800 ┆ segfault  ┆ 2017-02-0 ┆ 2017-02-0 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ So my     │
# │          ┆ when      ┆ 7 06:02:1 ┆ 7 06:18:3 ┆   ┆           ┆           ┆ Overflow  ┆ unordered │
# │          ┆ indexing  ┆ 9.583 UTC ┆ 6.600 UTC ┆   ┆           ┆           ┆           ┆ map is a  │
# │          ┆ [] into…  ┆           ┆           ┆   ┆           ┆           ┆           ┆ mappi…    │
# │ 41808100 ┆ Read file ┆ 2017-01-2 ┆ 2017-01-2 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ This is   │
# │          ┆ as hex in ┆ 3 13:59:2 ┆ 3 16:05:3 ┆   ┆           ┆           ┆ Overflow  ┆ my        │
# │          ┆ C         ┆ 4.080 UTC ┆ 2.263 UTC ┆   ┆           ┆           ┆           ┆ current   │
# │          ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ code: It  │
# │          ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ wo…       │
# │ 41993460 ┆ 500       ┆ 2017-02-0 ┆ 2017-02-0 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ Kindly    │
# │          ┆ Internal  ┆ 2 02:54:1 ┆ 2 02:54:1 ┆   ┆           ┆           ┆ Overflow  ┆ help me,  │
# │          ┆ Server    ┆ 2.757 UTC ┆ 2.757 UTC ┆   ┆           ┆           ┆           ┆ My Ubuntu │
# │          ┆ Error.    ┆           ┆           ┆   ┆           ┆           ┆           ┆ Serv…     │
# │          ┆ mal…      ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 41973876 ┆ Strange   ┆ 2017-02-0 ┆ 2017-02-0 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ I am      │
# │          ┆ behavior  ┆ 1 07:09:2 ┆ 2 09:33:5 ┆   ┆           ┆           ┆ Overflow  ┆ trying to │
# │          ┆ while     ┆ 5.650 UTC ┆ 2.140 UTC ┆   ┆           ┆           ┆           ┆ use       │
# │          ┆ calling…  ┆           ┆           ┆   ┆           ┆           ┆           ┆ REFPROPs  │
# │          ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ su…       │
# │ 41816885 ┆ Copying   ┆ 2017-01-2 ┆ 2017-01-2 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ I'm       │
# │          ┆ the lines ┆ 3 22:34:2 ┆ 8 13:55:5 ┆   ┆           ┆           ┆ Overflow  ┆ trying to │
# │          ┆ from a    ┆ 8.947 UTC ┆ 7.107 UTC ┆   ┆           ┆           ┆           ┆ copy the  │
# │          ┆ file …    ┆           ┆           ┆   ┆           ┆           ┆           ┆ file it…  │
# │ 41794627 ┆ Can't     ┆ 2017-01-2 ┆ 2017-03-0 ┆ … ┆ 0         ┆ 0         ┆ Stack     ┆ When I    │
# │          ┆ create    ┆ 2 18:28:3 ┆ 7 00:20:3 ┆   ┆           ┆           ┆ Overflow  ┆ deploy my │
# │          ┆ cron job  ┆ 9.233 UTC ┆ 4.963 UTC ┆   ┆           ┆           ┆           ┆ applicati │
# │          ┆ in Googl… ┆           ┆           ┆   ┆           ┆           ┆           ┆ on w…     │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import json
with open("./test.json", "a") as f:
    df_SO.write_json(f)

# %%
df_github = pl.read_parquet("./train-00000-of-00008.parquet")
df_github.head(5)
# Out:
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬────────────┬──────────┬───────────┬───────────┬───────────┐
# │ repository ┆ func_path_ ┆ func_name  ┆ whole_func ┆ language ┆ func_code ┆ func_docu ┆ func_code │
# │ _name      ┆ in_reposit ┆ ---        ┆ _string    ┆ ---      ┆ _string   ┆ mentation ┆ _url      │
# │ ---        ┆ ory        ┆ str        ┆ ---        ┆ str      ┆ ---       ┆ _string   ┆ ---       │
# │ str        ┆ ---        ┆            ┆ str        ┆          ┆ str       ┆ ---       ┆ str       │
# │            ┆ str        ┆            ┆            ┆          ┆           ┆ str       ┆           │
# ╞════════════╪════════════╪════════════╪════════════╪══════════╪═══════════╪═══════════╪═══════════╡
# │ proycon/py ┆ pynlpl/for ┆ AbstractEl ┆ def addids ┆ python   ┆ def addid ┆ Appends a ┆ https://g │
# │ nlpl       ┆ mats/folia ┆ ement.addi ┆ uffix(self ┆          ┆ suffix(se ┆ suffix to ┆ ithub.com │
# │            ┆ .py        ┆ dsuffix    ┆ ,          ┆          ┆ lf,       ┆ this      ┆ /proycon/ │
# │            ┆            ┆            ┆ idsuffix…  ┆          ┆ idsuffix… ┆ eleme…    ┆ pyn…      │
# │ proycon/py ┆ pynlpl/for ┆ AbstractEl ┆ def setpar ┆ python   ┆ def setpa ┆ Correct   ┆ https://g │
# │ nlpl       ┆ mats/folia ┆ ement.setp ┆ ents(self) ┆          ┆ rents(sel ┆ all       ┆ ithub.com │
# │            ┆ .py        ┆ arents     ┆ :          ┆          ┆ f):       ┆ parent    ┆ /proycon/ │
# │            ┆            ┆            ┆         …  ┆          ┆         … ┆ relations ┆ pyn…      │
# │            ┆            ┆            ┆            ┆          ┆           ┆ f…        ┆           │
# │ proycon/py ┆ pynlpl/for ┆ AbstractEl ┆ def setdoc ┆ python   ┆ def setdo ┆ Set a     ┆ https://g │
# │ nlpl       ┆ mats/folia ┆ ement.setd ┆ (self,newd ┆          ┆ c(self,ne ┆ different ┆ ithub.com │
# │            ┆ .py        ┆ oc         ┆ oc):       ┆          ┆ wdoc):    ┆ document. ┆ /proycon/ │
# │            ┆            ┆            ┆      …     ┆          ┆      …    ┆ Usua…     ┆ pyn…      │
# │ proycon/py ┆ pynlpl/for ┆ AbstractEl ┆ def hastex ┆ python   ┆ def haste ┆ Does this ┆ https://g │
# │ nlpl       ┆ mats/folia ┆ ement.hast ┆ t(self,cls ┆          ┆ xt(self,c ┆ element   ┆ ithub.com │
# │            ┆ .py        ┆ ext        ┆ ='current' ┆          ┆ ls='curre ┆ have text ┆ /proycon/ │
# │            ┆            ┆            ┆ …          ┆          ┆ nt'…      ┆ (o…       ┆ pyn…      │
# │ proycon/py ┆ pynlpl/for ┆ AbstractEl ┆ def haspho ┆ python   ┆ def hasph ┆ Does this ┆ https://g │
# │ nlpl       ┆ mats/folia ┆ ement.hasp ┆ n(self,cls ┆          ┆ on(self,c ┆ element   ┆ ithub.com │
# │            ┆ .py        ┆ hon        ┆ ='current' ┆          ┆ ls='curre ┆ have      ┆ /proycon/ │
# │            ┆            ┆            ┆ …          ┆          ┆ nt'…      ┆ phoneti…  ┆ pyn…      │
# └────────────┴────────────┴────────────┴────────────┴──────────┴───────────┴───────────┴───────────┘

# %%
from datetime import datetime, timezone

df_github = df_github.drop(['func_path_in_repository', "repository_name", "whole_func_string","func_code_string"]).rename({
    "func_documentation_string": "content",
    "func_code_url": "path",
}).with_columns(
    id = "doc_" + pl.col("func_name"),
    tags = pl.col("language").map_elements(lambda lang: [lang] if lang else [], return_dtype=pl.List(pl.String)),
    file_type = pl.lit("repository"),
    language = pl.lit("en"),
    github_stars = pl.lit(0),
    view_count = pl.lit(0),
    source = pl.lit("GitHub"),
    title = "Docstring Documentation of " + pl.col("func_name"),
    created_at = pl.lit(datetime.now(timezone.utc)),
    modified_at = pl.lit(datetime.now(timezone.utc))
).drop(['func_name'])
df_github.head(5)
# Out:
# shape: (5, 12)
# ┌──────────┬────────────┬────────────┬────────────┬───┬────────┬───────────┬───────────┬───────────┐
# │ language ┆ content    ┆ path       ┆ id         ┆ … ┆ source ┆ title     ┆ created_a ┆ modified_ │
# │ ---      ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---       ┆ t         ┆ at        │
# │ str      ┆ str        ┆ str        ┆ str        ┆   ┆ str    ┆ str       ┆ ---       ┆ ---       │
# │          ┆            ┆            ┆            ┆   ┆        ┆           ┆ datetime[ ┆ datetime[ │
# │          ┆            ┆            ┆            ┆   ┆        ┆           ┆ μs, UTC]  ┆ μs, UTC]  │
# ╞══════════╪════════════╪════════════╪════════════╪═══╪════════╪═══════════╪═══════════╪═══════════╡
# │ en       ┆ Appends a  ┆ https://gi ┆ doc_Abstra ┆ … ┆ GitHub ┆ Docstring ┆ 2025-06-0 ┆ 2025-06-0 │
# │          ┆ suffix to  ┆ thub.com/p ┆ ctElement. ┆   ┆        ┆ Documenta ┆ 6 13:05:1 ┆ 6 13:05:1 │
# │          ┆ this       ┆ roycon/pyn ┆ addidsuffi ┆   ┆        ┆ tion of   ┆ 2.578753  ┆ 2.578820  │
# │          ┆ eleme…     ┆ …          ┆ …          ┆   ┆        ┆ Abs…      ┆ UTC       ┆ UTC       │
# │ en       ┆ Correct    ┆ https://gi ┆ doc_Abstra ┆ … ┆ GitHub ┆ Docstring ┆ 2025-06-0 ┆ 2025-06-0 │
# │          ┆ all parent ┆ thub.com/p ┆ ctElement. ┆   ┆        ┆ Documenta ┆ 6 13:05:1 ┆ 6 13:05:1 │
# │          ┆ relations  ┆ roycon/pyn ┆ setparents ┆   ┆        ┆ tion of   ┆ 2.578753  ┆ 2.578820  │
# │          ┆ f…         ┆ …          ┆            ┆   ┆        ┆ Abs…      ┆ UTC       ┆ UTC       │
# │ en       ┆ Set a      ┆ https://gi ┆ doc_Abstra ┆ … ┆ GitHub ┆ Docstring ┆ 2025-06-0 ┆ 2025-06-0 │
# │          ┆ different  ┆ thub.com/p ┆ ctElement. ┆   ┆        ┆ Documenta ┆ 6 13:05:1 ┆ 6 13:05:1 │
# │          ┆ document.  ┆ roycon/pyn ┆ setdoc     ┆   ┆        ┆ tion of   ┆ 2.578753  ┆ 2.578820  │
# │          ┆ Usua…      ┆ …          ┆            ┆   ┆        ┆ Abs…      ┆ UTC       ┆ UTC       │
# │ en       ┆ Does this  ┆ https://gi ┆ doc_Abstra ┆ … ┆ GitHub ┆ Docstring ┆ 2025-06-0 ┆ 2025-06-0 │
# │          ┆ element    ┆ thub.com/p ┆ ctElement. ┆   ┆        ┆ Documenta ┆ 6 13:05:1 ┆ 6 13:05:1 │
# │          ┆ have text  ┆ roycon/pyn ┆ hastext    ┆   ┆        ┆ tion of   ┆ 2.578753  ┆ 2.578820  │
# │          ┆ (o…        ┆ …          ┆            ┆   ┆        ┆ Abs…      ┆ UTC       ┆ UTC       │
# │ en       ┆ Does this  ┆ https://gi ┆ doc_Abstra ┆ … ┆ GitHub ┆ Docstring ┆ 2025-06-0 ┆ 2025-06-0 │
# │          ┆ element    ┆ thub.com/p ┆ ctElement. ┆   ┆        ┆ Documenta ┆ 6 13:05:1 ┆ 6 13:05:1 │
# │          ┆ have       ┆ roycon/pyn ┆ hasphon    ┆   ┆        ┆ tion of   ┆ 2.578753  ┆ 2.578820  │
# │          ┆ phoneti…   ┆ …          ┆            ┆   ┆        ┆ Abs…      ┆ UTC       ┆ UTC       │
# └──────────┴────────────┴────────────┴────────────┴───┴────────┴───────────┴───────────┴───────────┘

# %%
with open("../sample_data/sample_dataset.json", "a") as f:
    df_github.sample(5000).write_json(f)

# %%
set(df_SO.columns).difference(set(df_github.columns))
# Out:
# {''}

# %%
final = pl.concat([df_github.sample(5000).select(ORDER), df_SO.select(ORDER)])

# %%
with open("../sample_data/sample_dataset.json", "a") as f:
    final.write_json(f)
